# %%
from tensorflow.keras.datasets import mnist
from tensorflow.keras.layers import Input, Dense, Reshape, Flatten, Dropout
from tensorflow.keras.layers import BatchNormalization, Activation, LeakyReLU, UpSampling2D, Conv2D
from tensorflow.keras.models import Sequential, Model

import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt

# %%
#이미지가 저장될 폴더가 없다면 만듭니다.
import os
if not os.path.exists("./gan_images"):
    os.makedirs("./gan_images")

# %%
seed=3
np.random.seed(seed)
tf.random.set_seed(seed)

# %%
#생성자 모델을 만듭니다.
generator = Sequential()
generator.add(Dense(128*7*7, input_dim=100, activation=LeakyReLU(0.2)))
generator.add(BatchNormalization())
generator.add(Reshape((7, 7, 128)))
generator.add(UpSampling2D())
generator.add(Conv2D(64, kernel_size=5, padding='same'))
generator.add(BatchNormalization())
generator.add(Activation(LeakyReLU(0.2)))
generator.add(UpSampling2D())
generator.add(Conv2D(1, kernel_size=5, padding='same', activation='tanh'))

# %%
#판별자 모델을 만듭니다.
discriminator = Sequential()
discriminator.add(Conv2D(64, kernel_size=5, strides=2, input_shape=(28,28,1), padding="same"))
discriminator.add(Activation(LeakyReLU(0.2)))
discriminator.add(Dropout(0.3))
discriminator.add(Conv2D(128, kernel_size=5, strides=2, padding="same"))
discriminator.add(Activation(LeakyReLU(0.2)))
discriminator.add(Dropout(0.3))
discriminator.add(Flatten())
discriminator.add(Dense(1, activation='sigmoid'))
discriminator.compile(loss='binary_crossentropy', optimizer='adam')
discriminator.trainable = False

# %%
#생성자와 판별자 모델을 연결시키는 gan 모델을 만듭니다.
ginput = Input(shape=(100,))
dis_output = discriminator(generator(ginput))
gan = Model(ginput, dis_output)
gan.compile(loss='binary_crossentropy', optimizer='adam')
gan.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 100)]             0
# _________________________________________________________________
# sequential (Sequential)      (None, 28, 28, 1)         865281
# _________________________________________________________________
# sequential_1 (Sequential)    (None, 1)                 212865
# =================================================================
# Total params: 1,078,146
# Trainable params: 852,609
# Non-trainable params: 225,537
# _________________________________________________________________

# %%
#신경망을 실행시키는 함수를 만듭니다.
def gan_train(epoch, batch_size, saving_interval):

  # MNIST 데이터 불러오기

  (X_train, _), (_, _) = mnist.load_data()  # 앞서 불러온 적 있는 MNIST를 다시 이용합니다. 단, 테스트과정은 필요없고 이미지만 사용할 것이기 때문에 X_train만 불러왔습니다.
  X_train = X_train.reshape(X_train.shape[0], 28, 28, 1).astype('float32')
  X_train = (X_train - 127.5) / 127.5  # 픽셀값은 0에서 255사이의 값입니다. 이전에 255로 나누어 줄때는 이를 0~1사이의 값으로 바꾸었던 것인데, 여기서는 127.5를 빼준 뒤 127.5로 나누어 줌으로 인해 -1에서 1사이의 값으로 바뀌게 됩니다.
  #X_train.shape, Y_train.shape, X_test.shape, Y_test.shape

  true = np.ones((batch_size, 1))
  fake = np.zeros((batch_size, 1))

  for i in range(epoch):
          # 실제 데이터를 판별자에 입력하는 부분입니다.
          idx = np.random.randint(0, X_train.shape[0], batch_size)
          imgs = X_train[idx]
          d_loss_real = discriminator.train_on_batch(imgs, true)

          #가상 이미지를 판별자에 입력하는 부분입니다.
          noise = np.random.normal(0, 1, (batch_size, 100))
          gen_imgs = generator.predict(noise)
          d_loss_fake = discriminator.train_on_batch(gen_imgs, fake)

          #판별자와 생성자의 오차를 계산합니다.
          d_loss = 0.5 * np.add(d_loss_real, d_loss_fake)
          g_loss = gan.train_on_batch(noise, true)

          print('epoch:%d' % i, ' d_loss:%.4f' % d_loss, ' g_loss:%.4f' % g_loss)

        # 이부분은 중간 과정을 이미지로 저장해 주는 부분입니다. 본 장의 주요 내용과 관련이 없어
        # 소스코드만 첨부합니다. 만들어진 이미지들은 gan_images 폴더에 저장됩니다.
          if i % saving_interval == 0:
              #r, c = 5, 5
              noise = np.random.normal(0, 1, (25, 100))
              gen_imgs = generator.predict(noise)

              # Rescale images 0 - 1
              gen_imgs = 0.5 * gen_imgs + 0.5

              fig, axs = plt.subplots(5, 5)
              count = 0
              for j in range(5):
                  for k in range(5):
                      axs[j, k].imshow(gen_imgs[count, :, :, 0], cmap='gray')
                      axs[j, k].axis('off')
                      count += 1
              fig.savefig("gan_images/gan_mnist_%d.png" % i)

gan_train(8001, 32, 200)  #4000번 반복되고(+1을 해 주는 것에 주의), 배치 사이즈는 32,  200번 마다 결과가 저장되게 하였습니다.
# Out:
# epoch:0  d_loss:0.7101  g_loss:0.6986
# epoch:1  d_loss:0.4343  g_loss:0.3320
# epoch:2  d_loss:0.5329  g_loss:0.1001
# epoch:3  d_loss:0.7553  g_loss:0.0607
# epoch:4  d_loss:0.6905  g_loss:0.1288
# epoch:5  d_loss:0.5407  g_loss:0.3769
# epoch:6  d_loss:0.4936  g_loss:0.7595
# epoch:7  d_loss:0.5136  g_loss:0.9291
# epoch:8  d_loss:0.5168  g_loss:1.0329
# epoch:9  d_loss:0.4700  g_loss:0.9853
# epoch:10  d_loss:0.3988  g_loss:0.9891
# epoch:11  d_loss:0.3570  g_loss:0.9710
# epoch:12  d_loss:0.3639  g_loss:0.9567
# epoch:13  d_loss:0.2794  g_loss:0.9123
# epoch:14  d_loss:0.4411  g_loss:0.8461
# epoch:15  d_loss:0.5186  g_loss:0.7166
# epoch:16  d_loss:0.5363  g_loss:1.0943
# epoch:17  d_loss:0.6844  g_loss:0.9518
# epoch:18  d_loss:0.7047  g_loss:0.6169
# epoch:19  d_loss:0.5250  g_loss:0.8182
# epoch:20  d_loss:0.6070  g_loss:0.7577
# epoch:21  d_loss:0.6272  g_loss:0.8223
# epoch:22  d_loss:0.6050  g_loss:0.8746
# epoch:23  d_loss:0.5020  g_loss:0.8237
# epoch:24  d_loss:0.5177  g_loss:0.8137
# epoch:25  d_loss:0.5403  g_loss:0.7826
# epoch:26  d_loss:0.5199  g_loss:0.7795
# epoch:27  d_loss:0.5543  g_loss:0.6539
# epoch:28  d_loss:0.5354  g_loss:0.6804
# epoch:29  d_loss:0.5448  g_loss:0.7286
# epoch:30  d_loss:0.4977  g_loss:0.7141
# epoch:31  d_loss:0.5058  g_loss:0.7692
# epoch:32  d_loss:0.5085  g_loss:0.7138
# epoch:33  d_loss:0.4341  g_loss:0.8970
# epoch:34  d_loss:0.4034  g_loss:0.8872
# epoch:35  d_loss:0.4728  g_loss:0.9213
# epoch:36  d_loss:0.4530  g_loss:0.9301
# epoch:37  d_loss:0.4345  g_loss:0.8499
# epoch:38  d_loss:0.4135  g_loss:1.0337
# epoch:39  d_loss:0.2936  g_loss:1.0181
# epoch:40  d_loss:0.3292  g_loss:1.0768
# epoch:41  d_loss:0.3982  g_loss:1.1016
# epoch:42  d_loss:0.3621  g_loss:1.1264
# epoch:43  d_loss:0.3001  g_loss:1.2443
# epoch:44  d_loss:0.2462  g_loss:1.4564
# epoch:45  d_loss:0.2603  g_loss:1.7871
# epoch:46  d_loss:0.2796  g_loss:1.7422
# epoch:47  d_loss:0.2097  g_loss:1.9856
# epoch:48  d_loss:0.1821  g_loss:2.0562
# epoch:49  d_loss:0.1896  g_loss:2.5885
# epoch:50  d_loss:0.1454  g_loss:2.8920
# epoch:51  d_loss:0.1619  g_loss:2.9658
# epoch:52  d_loss:0.1740  g_loss:2.9491
# epoch:53  d_loss:0.1535  g_loss:2.6993
# epoch:54  d_loss:0.1524  g_loss:2.9132
# epoch:55  d_loss:0.2563  g_loss:2.5537
# epoch:56  d_loss:0.4836  g_loss:2.1150
# epoch:57  d_loss:0.3143  g_loss:2.0529
# epoch:58  d_loss:0.3277  g_loss:2.3402
# epoch:59  d_loss:0.2504  g_loss:3.0367
# epoch:60  d_loss:0.3200  g_loss:2.3653
# epoch:61  d_loss:0.1155  g_loss:2.3118
# epoch:62  d_loss:0.0900  g_loss:2.9382
# epoch:63  d_loss:0.0679  g_loss:3.3360
# epoch:64  d_loss:0.1276  g_loss:3.4763
# epoch:65  d_loss:0.2209  g_loss:3.2163
# epoch:66  d_loss:0.2696  g_loss:3.0045
# epoch:67  d_loss:0.2748  g_loss:4.6140
# epoch:68  d_loss:0.8219  g_loss:3.5639
# epoch:69  d_loss:0.8924  g_loss:2.1494
# epoch:70  d_loss:0.5867  g_loss:2.1250
# epoch:71  d_loss:0.6750  g_loss:3.1124
# epoch:72  d_loss:0.6967  g_loss:2.8458
# epoch:73  d_loss:0.5328  g_loss:2.5308
# epoch:74  d_loss:0.3449  g_loss:3.5684
# epoch:75  d_loss:0.3585  g_loss:3.7261
# epoch:76  d_loss:0.3971  g_loss:2.5986
# epoch:77  d_loss:0.3694  g_loss:2.4555
# epoch:78  d_loss:0.3476  g_loss:2.4974
# epoch:79  d_loss:0.4008  g_loss:1.9779
# epoch:80  d_loss:0.4326  g_loss:1.8649
# epoch:81  d_loss:0.5513  g_loss:1.2740
# epoch:82  d_loss:0.4019  g_loss:1.2988
# epoch:83  d_loss:0.6724  g_loss:1.2773
# epoch:84  d_loss:0.7568  g_loss:1.4378
# epoch:85  d_loss:0.5914  g_loss:1.6664
# epoch:86  d_loss:0.9044  g_loss:1.5678
# epoch:87  d_loss:0.6911  g_loss:1.4509
# epoch:88  d_loss:0.4870  g_loss:1.9914
# epoch:89  d_loss:0.4394  g_loss:3.0809
# epoch:90  d_loss:0.2281  g_loss:3.6437
# epoch:91  d_loss:0.2097  g_loss:4.0961
# epoch:92  d_loss:0.2882  g_loss:3.2247
# epoch:93  d_loss:0.3185  g_loss:3.2558
# epoch:94  d_loss:0.3740  g_loss:4.4177
# epoch:95  d_loss:0.4140  g_loss:4.6794
# epoch:96  d_loss:0.4737  g_loss:4.6974
# epoch:97  d_loss:1.1315  g_loss:3.2661
# epoch:98  d_loss:1.0970  g_loss:2.7180
# epoch:99  d_loss:0.7527  g_loss:3.6742
# epoch:100  d_loss:0.8517  g_loss:3.6210
# epoch:101  d_loss:1.0468  g_loss:3.5131
# epoch:102  d_loss:0.8257  g_loss:2.5775
# epoch:103  d_loss:0.8601  g_loss:1.7991
# epoch:104  d_loss:0.7458  g_loss:1.3877
# epoch:105  d_loss:0.6211  g_loss:1.1055
# epoch:106  d_loss:0.5082  g_loss:1.4856
# epoch:107  d_loss:0.4587  g_loss:1.4718
# epoch:108  d_loss:0.5147  g_loss:1.6537
# epoch:109  d_loss:0.4633  g_loss:1.3961
# epoch:110  d_loss:0.3577  g_loss:1.6219
# epoch:111  d_loss:0.4541  g_loss:1.3035
# epoch:112  d_loss:0.4028  g_loss:1.0711
# epoch:113  d_loss:0.4537  g_loss:1.0415
# epoch:114  d_loss:0.5283  g_loss:0.8538
# epoch:115  d_loss:0.4095  g_loss:1.0183
# epoch:116  d_loss:0.4180  g_loss:1.2922
# epoch:117  d_loss:0.4114  g_loss:0.9688
# epoch:118  d_loss:0.4604  g_loss:0.8812
# epoch:119  d_loss:0.3081  g_loss:1.1452
# epoch:120  d_loss:0.4733  g_loss:0.9970
# epoch:121  d_loss:0.5548  g_loss:0.8609
# epoch:122  d_loss:0.6295  g_loss:0.9134
# epoch:123  d_loss:0.5392  g_loss:0.8224
# epoch:124  d_loss:0.4486  g_loss:1.0853
# epoch:125  d_loss:0.5983  g_loss:1.0311
# epoch:126  d_loss:0.5894  g_loss:0.9724
# epoch:127  d_loss:0.5497  g_loss:1.1147
# epoch:128  d_loss:0.5636  g_loss:1.0995
# epoch:129  d_loss:0.5010  g_loss:1.1592
# epoch:130  d_loss:0.4957  g_loss:1.0211
# epoch:131  d_loss:0.5547  g_loss:1.1897
# epoch:132  d_loss:0.5122  g_loss:1.0053
# epoch:133  d_loss:0.6315  g_loss:0.9751
# epoch:134  d_loss:0.4899  g_loss:1.0725
# epoch:135  d_loss:0.5899  g_loss:1.0322
# epoch:136  d_loss:0.4950  g_loss:1.1635
# epoch:137  d_loss:0.4937  g_loss:1.3417
# epoch:138  d_loss:0.5188  g_loss:1.3740
# epoch:139  d_loss:0.4543  g_loss:1.4978
# epoch:140  d_loss:0.4518  g_loss:1.5582
# epoch:141  d_loss:0.4978  g_loss:1.6296
# epoch:142  d_loss:0.4387  g_loss:1.4646
# epoch:143  d_loss:0.3964  g_loss:1.3893
# epoch:144  d_loss:0.4134  g_loss:1.6210
# epoch:145  d_loss:0.3831  g_loss:1.6017
# epoch:146  d_loss:0.4629  g_loss:1.6389
# epoch:147  d_loss:0.4566  g_loss:1.7978
# epoch:148  d_loss:0.5440  g_loss:1.6771
# epoch:149  d_loss:0.5201  g_loss:1.6156
# epoch:150  d_loss:0.5218  g_loss:1.4988
# epoch:151  d_loss:0.5741  g_loss:1.6849
# epoch:152  d_loss:0.6174  g_loss:1.6593
# epoch:153  d_loss:0.5491  g_loss:1.5699
# epoch:154  d_loss:0.5060  g_loss:1.4950
# epoch:155  d_loss:0.5934  g_loss:1.1382
# epoch:156  d_loss:0.5089  g_loss:1.4021
# epoch:157  d_loss:0.5631  g_loss:1.3082
# epoch:158  d_loss:0.5312  g_loss:1.3047
# epoch:159  d_loss:0.4733  g_loss:1.5420
# epoch:160  d_loss:0.5535  g_loss:1.6182
# epoch:161  d_loss:0.4881  g_loss:1.6892
# epoch:162  d_loss:0.5065  g_loss:1.5447
# epoch:163  d_loss:0.5533  g_loss:1.5129
# epoch:164  d_loss:0.4723  g_loss:1.3026
# epoch:165  d_loss:0.5296  g_loss:1.2832
# epoch:166  d_loss:0.4716  g_loss:1.5546
# epoch:167  d_loss:0.4448  g_loss:1.6402
# epoch:168  d_loss:0.3765  g_loss:1.8375
# epoch:169  d_loss:0.4799  g_loss:1.4629
# epoch:170  d_loss:0.4481  g_loss:1.5679
# epoch:171  d_loss:0.4430  g_loss:1.5330
# epoch:172  d_loss:0.4411  g_loss:1.3979
# epoch:173  d_loss:0.3659  g_loss:1.7042
# epoch:174  d_loss:0.3963  g_loss:1.7586
# epoch:175  d_loss:0.3317  g_loss:2.1100
# epoch:176  d_loss:0.4643  g_loss:1.8014
# epoch:177  d_loss:0.4458  g_loss:1.6910
# epoch:178  d_loss:0.2639  g_loss:1.8103
# epoch:179  d_loss:0.3654  g_loss:1.5873
# epoch:180  d_loss:0.4501  g_loss:1.6769
# epoch:181  d_loss:0.3004  g_loss:1.6766
# epoch:182  d_loss:0.4139  g_loss:1.9694
# epoch:183  d_loss:0.3304  g_loss:2.1627
# epoch:184  d_loss:0.4333  g_loss:1.8876
# epoch:185  d_loss:0.4689  g_loss:1.9236
# epoch:186  d_loss:0.3407  g_loss:1.8098
# epoch:187  d_loss:0.5090  g_loss:1.6814
# epoch:188  d_loss:0.4380  g_loss:1.6693
# epoch:189  d_loss:0.4085  g_loss:1.6757
# epoch:190  d_loss:0.4913  g_loss:1.8356
# epoch:191  d_loss:0.4634  g_loss:1.8151
# epoch:192  d_loss:0.3917  g_loss:2.1211
# epoch:193  d_loss:0.5784  g_loss:1.7685
# epoch:194  d_loss:0.6244  g_loss:1.4286
# epoch:195  d_loss:0.5096  g_loss:1.4366
# epoch:196  d_loss:0.4639  g_loss:1.6575
# epoch:197  d_loss:0.5976  g_loss:1.9265
# epoch:198  d_loss:0.5239  g_loss:1.6656
# epoch:199  d_loss:0.5460  g_loss:1.7866
# epoch:200  d_loss:0.6050  g_loss:1.6629
# epoch:201  d_loss:0.6193  g_loss:1.7193
# epoch:202  d_loss:0.5341  g_loss:1.5851
# epoch:203  d_loss:0.4722  g_loss:1.7136
# epoch:204  d_loss:0.4583  g_loss:1.9664
# epoch:205  d_loss:0.4708  g_loss:1.8400
# epoch:206  d_loss:0.4828  g_loss:1.9090
# epoch:207  d_loss:0.5247  g_loss:1.5563
# epoch:208  d_loss:0.4359  g_loss:1.8788
# epoch:209  d_loss:0.3403  g_loss:2.0806
# epoch:210  d_loss:0.4716  g_loss:1.8950
# epoch:211  d_loss:0.4064  g_loss:1.8680
# epoch:212  d_loss:0.4452  g_loss:1.9381
# epoch:213  d_loss:0.5018  g_loss:1.6587
# epoch:214  d_loss:0.5154  g_loss:1.7062
# epoch:215  d_loss:0.4033  g_loss:1.6147
# epoch:216  d_loss:0.4626  g_loss:1.6681
# epoch:217  d_loss:0.3428  g_loss:2.2676
# epoch:218  d_loss:0.5482  g_loss:1.8738
# epoch:219  d_loss:0.5680  g_loss:1.8971
# epoch:220  d_loss:0.4541  g_loss:1.7210
# epoch:221  d_loss:0.4621  g_loss:1.6066
# epoch:222  d_loss:0.5040  g_loss:1.4354
# epoch:223  d_loss:0.4838  g_loss:1.6834
# epoch:224  d_loss:0.4707  g_loss:1.9661
# epoch:225  d_loss:0.4239  g_loss:1.9406
# epoch:226  d_loss:0.4092  g_loss:1.9829
# epoch:227  d_loss:0.5543  g_loss:1.9478
# epoch:228  d_loss:0.7121  g_loss:1.6125
# epoch:229  d_loss:0.4353  g_loss:1.7671
# epoch:230  d_loss:0.6154  g_loss:1.6066
# epoch:231  d_loss:0.6514  g_loss:1.4159
# epoch:232  d_loss:0.7395  g_loss:1.8634
# epoch:233  d_loss:0.6034  g_loss:1.6428
# epoch:234  d_loss:0.4997  g_loss:1.6948
# epoch:235  d_loss:0.4337  g_loss:1.7102
# epoch:236  d_loss:0.4212  g_loss:1.3041
# epoch:237  d_loss:0.4887  g_loss:1.7470
# epoch:238  d_loss:0.4066  g_loss:1.5958
# epoch:239  d_loss:0.4127  g_loss:1.7867
# epoch:240  d_loss:0.4463  g_loss:2.0193
# epoch:241  d_loss:0.5323  g_loss:2.1101
# epoch:242  d_loss:0.4837  g_loss:1.9396
# epoch:243  d_loss:0.4903  g_loss:1.6055
# epoch:244  d_loss:0.4052  g_loss:1.8872
# epoch:245  d_loss:0.4262  g_loss:2.0159
# epoch:246  d_loss:0.3909  g_loss:1.7787
# epoch:247  d_loss:0.3311  g_loss:2.4819
# epoch:248  d_loss:0.3694  g_loss:2.5484
# epoch:249  d_loss:0.2762  g_loss:2.4552
# epoch:250  d_loss:0.4034  g_loss:2.4509
# epoch:251  d_loss:0.4094  g_loss:2.5134
# epoch:252  d_loss:0.4097  g_loss:2.7316
# epoch:253  d_loss:0.3829  g_loss:3.0966
# epoch:254  d_loss:0.3303  g_loss:2.5382
# epoch:255  d_loss:0.3366  g_loss:2.5182
# epoch:256  d_loss:0.4355  g_loss:1.7809
# epoch:257  d_loss:0.4204  g_loss:2.0834
# epoch:258  d_loss:0.3672  g_loss:2.4233
# epoch:259  d_loss:0.4200  g_loss:2.5253
# epoch:260  d_loss:0.3481  g_loss:2.3307
# epoch:261  d_loss:0.4639  g_loss:1.9770
# epoch:262  d_loss:0.4742  g_loss:1.9784
# epoch:263  d_loss:0.5091  g_loss:1.7285
# epoch:264  d_loss:0.5359  g_loss:1.7032
# epoch:265  d_loss:0.6142  g_loss:1.4636
# epoch:266  d_loss:0.4523  g_loss:1.8156
# epoch:267  d_loss:0.5885  g_loss:1.7758
# epoch:268  d_loss:0.6106  g_loss:1.8016
# epoch:269  d_loss:0.5068  g_loss:1.7368
# epoch:270  d_loss:0.5452  g_loss:1.4424
# epoch:271  d_loss:0.4022  g_loss:1.5781
# epoch:272  d_loss:0.5558  g_loss:1.4357
# epoch:273  d_loss:0.4724  g_loss:1.5441
# epoch:274  d_loss:0.5791  g_loss:1.8242
# epoch:275  d_loss:0.4701  g_loss:1.9846
# epoch:276  d_loss:0.6220  g_loss:1.9240
# epoch:277  d_loss:0.7443  g_loss:1.4856
# epoch:278  d_loss:0.4307  g_loss:2.0944
# epoch:279  d_loss:0.4635  g_loss:1.6336
# epoch:280  d_loss:0.3923  g_loss:1.8425
# epoch:281  d_loss:0.4340  g_loss:1.7458
# epoch:282  d_loss:0.4342  g_loss:2.0315
# epoch:283  d_loss:0.4651  g_loss:2.0611
# epoch:284  d_loss:0.3646  g_loss:1.9406
# epoch:285  d_loss:0.4481  g_loss:1.6740
# epoch:286  d_loss:0.3555  g_loss:2.0797
# epoch:287  d_loss:0.3584  g_loss:2.1544
# epoch:288  d_loss:0.2918  g_loss:2.6164
# epoch:289  d_loss:0.3910  g_loss:2.7868
# epoch:290  d_loss:0.5888  g_loss:1.4787
# epoch:291  d_loss:0.4584  g_loss:1.2923
# epoch:292  d_loss:0.4595  g_loss:1.8330
# epoch:293  d_loss:0.3688  g_loss:2.0629
# epoch:294  d_loss:0.3234  g_loss:2.6351
# epoch:295  d_loss:0.5640  g_loss:1.7499
# epoch:296  d_loss:0.4822  g_loss:1.9009
# epoch:297  d_loss:0.3930  g_loss:1.5423
# epoch:298  d_loss:0.3683  g_loss:1.9372
# epoch:299  d_loss:0.4186  g_loss:1.9825
# epoch:300  d_loss:0.3508  g_loss:2.0166
# epoch:301  d_loss:0.3555  g_loss:2.3756
# epoch:302  d_loss:0.3491  g_loss:2.5860
# epoch:303  d_loss:0.4092  g_loss:1.9959
# epoch:304  d_loss:0.3502  g_loss:2.1989
# epoch:305  d_loss:0.3990  g_loss:2.1420
# epoch:306  d_loss:0.4607  g_loss:1.4553
# epoch:307  d_loss:0.3517  g_loss:2.0508
# epoch:308  d_loss:0.3646  g_loss:2.1707
# epoch:309  d_loss:0.4049  g_loss:2.4666
# epoch:310  d_loss:0.4279  g_loss:2.4126
# epoch:311  d_loss:0.3625  g_loss:1.8899
# epoch:312  d_loss:0.4059  g_loss:2.0274
# epoch:313  d_loss:0.4720  g_loss:2.0482
# epoch:314  d_loss:0.3283  g_loss:2.2566
# epoch:315  d_loss:0.3186  g_loss:2.0682
# epoch:316  d_loss:0.2907  g_loss:2.7267
# epoch:317  d_loss:0.5344  g_loss:2.1548
# epoch:318  d_loss:0.4947  g_loss:1.9061
# epoch:319  d_loss:0.6797  g_loss:2.0757
# epoch:320  d_loss:0.4084  g_loss:2.3378
# epoch:321  d_loss:0.4189  g_loss:2.3916
# epoch:322  d_loss:0.5954  g_loss:2.2584
# epoch:323  d_loss:0.6924  g_loss:1.9452
# epoch:324  d_loss:0.3966  g_loss:1.8066
# epoch:325  d_loss:0.4077  g_loss:1.8053
# epoch:326  d_loss:0.4724  g_loss:1.8714
# epoch:327  d_loss:0.4168  g_loss:1.7685
# epoch:328  d_loss:0.5492  g_loss:1.6819
# epoch:329  d_loss:0.3776  g_loss:2.2655
# epoch:330  d_loss:0.3444  g_loss:2.6399
# epoch:331  d_loss:0.5792  g_loss:2.5564
# epoch:332  d_loss:0.4382  g_loss:2.5852
# epoch:333  d_loss:0.4114  g_loss:1.8810
# epoch:334  d_loss:0.3946  g_loss:1.7189
# epoch:335  d_loss:0.3507  g_loss:1.8047
# epoch:336  d_loss:0.2990  g_loss:1.8206
# epoch:337  d_loss:0.2749  g_loss:2.7478
# epoch:338  d_loss:0.3044  g_loss:2.9221
# epoch:339  d_loss:0.4371  g_loss:2.5457
# epoch:340  d_loss:0.4123  g_loss:1.9011
# epoch:341  d_loss:0.3407  g_loss:2.4549
# epoch:342  d_loss:0.4813  g_loss:2.2926
# epoch:343  d_loss:0.2895  g_loss:2.8891
# epoch:344  d_loss:0.3651  g_loss:3.1199
# epoch:345  d_loss:0.3457  g_loss:2.8993
# epoch:346  d_loss:0.5295  g_loss:2.1784
# epoch:347  d_loss:0.4732  g_loss:1.8887
# epoch:348  d_loss:0.4243  g_loss:2.5336
# epoch:349  d_loss:0.2465  g_loss:2.8054
# epoch:350  d_loss:0.3542  g_loss:3.1660
# epoch:351  d_loss:0.3909  g_loss:2.6374
# epoch:352  d_loss:0.3446  g_loss:2.7316
# epoch:353  d_loss:0.3020  g_loss:2.3477
# epoch:354  d_loss:0.3592  g_loss:1.9270
# epoch:355  d_loss:0.3373  g_loss:2.3302
# epoch:356  d_loss:0.3056  g_loss:2.1749
# epoch:357  d_loss:0.2728  g_loss:2.3333
# epoch:358  d_loss:0.3208  g_loss:2.4481
# epoch:359  d_loss:0.3569  g_loss:2.4850
# epoch:360  d_loss:0.3256  g_loss:2.9055
# epoch:361  d_loss:0.3362  g_loss:2.7329
# epoch:362  d_loss:0.2857  g_loss:2.7024
# epoch:363  d_loss:0.2415  g_loss:2.2028
# epoch:364  d_loss:0.3132  g_loss:1.8793
# epoch:365  d_loss:0.2196  g_loss:2.3989
# epoch:366  d_loss:0.3313  g_loss:2.3456
# epoch:367  d_loss:0.3101  g_loss:2.7053
# epoch:368  d_loss:0.4176  g_loss:2.6599
# epoch:369  d_loss:0.3721  g_loss:2.2037
# epoch:370  d_loss:0.4251  g_loss:1.9427
# epoch:371  d_loss:0.3149  g_loss:2.3199
# epoch:372  d_loss:0.2692  g_loss:2.3381
# epoch:373  d_loss:0.3164  g_loss:2.4715
# epoch:374  d_loss:0.3912  g_loss:2.6805
# epoch:375  d_loss:0.5339  g_loss:1.8673
# epoch:376  d_loss:0.5369  g_loss:1.5626
# epoch:377  d_loss:0.4276  g_loss:1.5350
# epoch:378  d_loss:0.3717  g_loss:1.8466
# epoch:379  d_loss:0.2581  g_loss:2.2308
# epoch:380  d_loss:0.3220  g_loss:2.4820
# epoch:381  d_loss:0.3522  g_loss:2.3896
# epoch:382  d_loss:0.3218  g_loss:2.0298
# epoch:383  d_loss:0.4550  g_loss:1.9206
# epoch:384  d_loss:0.4460  g_loss:1.5632
# epoch:385  d_loss:0.4202  g_loss:2.2836
# epoch:386  d_loss:0.3396  g_loss:2.1196
# epoch:387  d_loss:0.4248  g_loss:2.3371
# epoch:388  d_loss:0.4674  g_loss:2.5366
# epoch:389  d_loss:0.4463  g_loss:2.3757
# epoch:390  d_loss:0.4633  g_loss:2.1277
# epoch:391  d_loss:0.4054  g_loss:2.3831
# epoch:392  d_loss:0.4379  g_loss:2.1019
# epoch:393  d_loss:0.2945  g_loss:2.8428
# epoch:394  d_loss:0.3413  g_loss:2.9528
# epoch:395  d_loss:0.3748  g_loss:2.7224
# epoch:396  d_loss:0.3566  g_loss:2.1705
# epoch:397  d_loss:0.2243  g_loss:1.9969
# epoch:398  d_loss:0.4007  g_loss:2.0527
# epoch:399  d_loss:0.3859  g_loss:2.6094
# epoch:400  d_loss:0.2484  g_loss:2.9994
# epoch:401  d_loss:0.3990  g_loss:3.1711
# epoch:402  d_loss:0.3023  g_loss:3.4365
# epoch:403  d_loss:0.3747  g_loss:2.6547
# epoch:404  d_loss:0.3584  g_loss:2.0790
# epoch:405  d_loss:0.3814  g_loss:1.8794
# epoch:406  d_loss:0.3351  g_loss:2.1472
# epoch:407  d_loss:0.3847  g_loss:1.9886
# epoch:408  d_loss:0.3132  g_loss:2.0513
# epoch:409  d_loss:0.4354  g_loss:2.3156
# epoch:410  d_loss:0.3911  g_loss:2.2753
# epoch:411  d_loss:0.3931  g_loss:1.8701
# epoch:412  d_loss:0.4582  g_loss:1.7733
# epoch:413  d_loss:0.3518  g_loss:1.9599
# epoch:414  d_loss:0.4742  g_loss:2.1087
# epoch:415  d_loss:0.4005  g_loss:2.6859
# epoch:416  d_loss:0.3328  g_loss:2.6856
# epoch:417  d_loss:0.3753  g_loss:2.5248
# epoch:418  d_loss:0.3583  g_loss:2.1182
# epoch:419  d_loss:0.3835  g_loss:1.7277
# epoch:420  d_loss:0.3840  g_loss:2.0205
# epoch:421  d_loss:0.3031  g_loss:2.3436
# epoch:422  d_loss:0.3133  g_loss:2.6258
# epoch:423  d_loss:0.4200  g_loss:2.6361
# epoch:424  d_loss:0.4473  g_loss:2.6003
# epoch:425  d_loss:0.2420  g_loss:2.6092
# epoch:426  d_loss:0.3165  g_loss:2.1334
# epoch:427  d_loss:0.3263  g_loss:2.4177
# epoch:428  d_loss:0.3328  g_loss:2.3304
# epoch:429  d_loss:0.3308  g_loss:2.8076
# epoch:430  d_loss:0.2175  g_loss:2.8978
# epoch:431  d_loss:0.2577  g_loss:3.0355
# epoch:432  d_loss:0.2629  g_loss:2.9046
# epoch:433  d_loss:0.3469  g_loss:3.0659
# epoch:434  d_loss:0.3034  g_loss:2.9560
# epoch:435  d_loss:0.2211  g_loss:2.1989
# epoch:436  d_loss:0.3376  g_loss:2.5286
# epoch:437  d_loss:0.2392  g_loss:2.4211
# epoch:438  d_loss:0.3579  g_loss:2.9074
# epoch:439  d_loss:0.3229  g_loss:2.7585
# epoch:440  d_loss:0.3060  g_loss:2.9390
# epoch:441  d_loss:0.3267  g_loss:2.3164
# epoch:442  d_loss:0.3272  g_loss:2.3005
# epoch:443  d_loss:0.3825  g_loss:2.1674
# epoch:444  d_loss:0.4073  g_loss:2.2398
# epoch:445  d_loss:0.4864  g_loss:1.7868
# epoch:446  d_loss:0.3971  g_loss:1.5840
# epoch:447  d_loss:0.5134  g_loss:1.6452
# epoch:448  d_loss:0.3424  g_loss:2.5554
# epoch:449  d_loss:0.4088  g_loss:2.7730
# epoch:450  d_loss:0.5256  g_loss:2.3241
# epoch:451  d_loss:0.4186  g_loss:1.8661
# epoch:452  d_loss:0.4478  g_loss:1.6744
# epoch:453  d_loss:0.4973  g_loss:1.5323
# epoch:454  d_loss:0.4038  g_loss:2.0488
# epoch:455  d_loss:0.4951  g_loss:2.0091
# epoch:456  d_loss:0.4720  g_loss:2.0090
# epoch:457  d_loss:0.3158  g_loss:1.9811
# epoch:458  d_loss:0.3815  g_loss:1.8458
# epoch:459  d_loss:0.2482  g_loss:2.3276
# epoch:460  d_loss:0.2550  g_loss:2.5055
# epoch:461  d_loss:0.2304  g_loss:2.6202
# epoch:462  d_loss:0.2717  g_loss:2.6348
# epoch:463  d_loss:0.2144  g_loss:2.5926
# epoch:464  d_loss:0.1880  g_loss:2.6220
# epoch:465  d_loss:0.2690  g_loss:2.5819
# epoch:466  d_loss:0.2689  g_loss:2.5880
# epoch:467  d_loss:0.3415  g_loss:2.8188
# epoch:468  d_loss:0.1981  g_loss:3.0476
# epoch:469  d_loss:0.2306  g_loss:3.3513
# epoch:470  d_loss:0.3184  g_loss:3.2506
# epoch:471  d_loss:0.1939  g_loss:2.9123
# epoch:472  d_loss:0.2163  g_loss:1.8414
# epoch:473  d_loss:0.2801  g_loss:2.1107
# epoch:474  d_loss:0.2621  g_loss:2.5939
# epoch:475  d_loss:0.1918  g_loss:3.5670
# epoch:476  d_loss:0.2755  g_loss:3.1005
# epoch:477  d_loss:0.2350  g_loss:3.2367
# epoch:478  d_loss:0.2044  g_loss:3.1236
# epoch:479  d_loss:0.2625  g_loss:3.0995
# epoch:480  d_loss:0.2312  g_loss:2.8765
# epoch:481  d_loss:0.1912  g_loss:2.7266
# epoch:482  d_loss:0.2849  g_loss:2.6615
# epoch:483  d_loss:0.2644  g_loss:2.1193
# epoch:484  d_loss:0.2914  g_loss:2.0519
# epoch:485  d_loss:0.0833  g_loss:3.3573
# epoch:486  d_loss:0.1838  g_loss:2.8125
# epoch:487  d_loss:0.4857  g_loss:2.5877
# epoch:488  d_loss:0.2910  g_loss:2.7335
# epoch:489  d_loss:0.2054  g_loss:2.8200
# epoch:490  d_loss:0.3374  g_loss:2.5922
# epoch:491  d_loss:0.2392  g_loss:2.9606
# epoch:492  d_loss:0.1916  g_loss:2.7955
# epoch:493  d_loss:0.3053  g_loss:2.9522
# epoch:494  d_loss:0.3230  g_loss:3.2135
# epoch:495  d_loss:0.3872  g_loss:2.5080
# epoch:496  d_loss:0.2596  g_loss:2.7431
# epoch:497  d_loss:0.2817  g_loss:1.8245
# epoch:498  d_loss:0.4785  g_loss:1.9143
# epoch:499  d_loss:0.2343  g_loss:1.9062
# epoch:500  d_loss:0.3486  g_loss:2.4306
# epoch:501  d_loss:0.2827  g_loss:2.7046
# epoch:502  d_loss:0.2786  g_loss:3.4330
# epoch:503  d_loss:0.4226  g_loss:2.7400
# epoch:504  d_loss:0.3868  g_loss:1.8378
# epoch:505  d_loss:0.2164  g_loss:2.3471
# epoch:506  d_loss:0.2734  g_loss:2.2647
# epoch:507  d_loss:0.1955  g_loss:2.9811
# epoch:508  d_loss:0.1653  g_loss:3.7066
# epoch:509  d_loss:0.1757  g_loss:4.0649
# epoch:510  d_loss:0.1933  g_loss:3.5510
# epoch:511  d_loss:0.2543  g_loss:4.0785
# epoch:512  d_loss:0.5214  g_loss:2.8392
# epoch:513  d_loss:0.2249  g_loss:2.9962
# epoch:514  d_loss:0.1980  g_loss:3.4566
# epoch:515  d_loss:0.2267  g_loss:3.5412
# epoch:516  d_loss:0.1775  g_loss:4.0019
# epoch:517  d_loss:0.2919  g_loss:3.0115
# epoch:518  d_loss:0.3270  g_loss:2.7047
# epoch:519  d_loss:0.1321  g_loss:2.3993
# epoch:520  d_loss:0.2187  g_loss:2.2589
# epoch:521  d_loss:0.2455  g_loss:2.7066
# epoch:522  d_loss:0.1782  g_loss:3.3706
# epoch:523  d_loss:0.1877  g_loss:4.3321
# epoch:524  d_loss:0.2770  g_loss:3.6778
# epoch:525  d_loss:0.1898  g_loss:3.2673
# epoch:526  d_loss:0.2206  g_loss:2.1703
# epoch:527  d_loss:0.3445  g_loss:1.8940
# epoch:528  d_loss:0.3190  g_loss:2.6224
# epoch:529  d_loss:0.2058  g_loss:2.6392
# epoch:530  d_loss:0.1444  g_loss:4.2146
# epoch:531  d_loss:0.1822  g_loss:3.4824
# epoch:532  d_loss:0.2935  g_loss:2.8382
# epoch:533  d_loss:0.2690  g_loss:2.6868
# epoch:534  d_loss:0.2297  g_loss:1.7908
# epoch:535  d_loss:0.2481  g_loss:2.2489
# epoch:536  d_loss:0.1047  g_loss:2.8639
# epoch:537  d_loss:0.1968  g_loss:3.1845
# epoch:538  d_loss:0.3780  g_loss:2.7929
# epoch:539  d_loss:0.3971  g_loss:1.9204
# epoch:540  d_loss:0.3547  g_loss:1.7926
# epoch:541  d_loss:0.1679  g_loss:2.4793
# epoch:542  d_loss:0.3039  g_loss:3.0357
# epoch:543  d_loss:0.4917  g_loss:2.3876
# epoch:544  d_loss:0.3155  g_loss:2.3979
# epoch:545  d_loss:0.3710  g_loss:1.8786
# epoch:546  d_loss:0.4549  g_loss:2.1318
# epoch:547  d_loss:0.3836  g_loss:2.1396
# epoch:548  d_loss:0.3073  g_loss:2.7480
# epoch:549  d_loss:0.2716  g_loss:2.5300
# epoch:550  d_loss:0.2475  g_loss:3.1878
# epoch:551  d_loss:0.3340  g_loss:2.4598
# epoch:552  d_loss:0.3970  g_loss:2.7312
# epoch:553  d_loss:0.4002  g_loss:1.9535
# epoch:554  d_loss:0.2167  g_loss:2.4849
# epoch:555  d_loss:0.2588  g_loss:2.7930
# epoch:556  d_loss:0.1910  g_loss:2.9018
# epoch:557  d_loss:0.1953  g_loss:3.5246
# epoch:558  d_loss:0.1715  g_loss:3.5272
# epoch:559  d_loss:0.1650  g_loss:2.5097
# epoch:560  d_loss:0.2177  g_loss:2.3231
# epoch:561  d_loss:0.3178  g_loss:2.3740
# epoch:562  d_loss:0.2008  g_loss:2.6717
# epoch:563  d_loss:0.2249  g_loss:2.8704
# epoch:564  d_loss:0.2055  g_loss:3.0871
# epoch:565  d_loss:0.1951  g_loss:2.7875
# epoch:566  d_loss:0.1831  g_loss:3.0237
# epoch:567  d_loss:0.2017  g_loss:3.1249
# epoch:568  d_loss:0.2080  g_loss:2.7485
# epoch:569  d_loss:0.2252  g_loss:2.4835
# epoch:570  d_loss:0.1725  g_loss:2.6737
# epoch:571  d_loss:0.2059  g_loss:3.3204
# epoch:572  d_loss:0.1271  g_loss:3.4584
# epoch:573  d_loss:0.2658  g_loss:2.7760
# epoch:574  d_loss:0.1804  g_loss:2.6002
# epoch:575  d_loss:0.1150  g_loss:3.2866
# epoch:576  d_loss:0.3308  g_loss:2.6912
# epoch:577  d_loss:0.1219  g_loss:2.8424
# epoch:578  d_loss:0.1750  g_loss:2.8349
# epoch:579  d_loss:0.1567  g_loss:3.0855
# epoch:580  d_loss:0.2358  g_loss:2.8175
# epoch:581  d_loss:0.1573  g_loss:3.1078
# epoch:582  d_loss:0.2293  g_loss:2.7356
# epoch:583  d_loss:0.2132  g_loss:2.5151
# epoch:584  d_loss:0.2785  g_loss:1.8664
# epoch:585  d_loss:0.4007  g_loss:2.2254
# epoch:586  d_loss:0.2716  g_loss:2.9793
# epoch:587  d_loss:0.2727  g_loss:3.2945
# epoch:588  d_loss:0.6119  g_loss:1.9605
# epoch:589  d_loss:0.6479  g_loss:1.1326
# epoch:590  d_loss:0.4947  g_loss:2.0221
# epoch:591  d_loss:0.2973  g_loss:3.7849
# epoch:592  d_loss:0.3817  g_loss:3.5614
# epoch:593  d_loss:0.4285  g_loss:2.3810
# epoch:594  d_loss:0.4364  g_loss:1.8452
# epoch:595  d_loss:0.6691  g_loss:1.9267
# epoch:596  d_loss:0.4939  g_loss:2.0636
# epoch:597  d_loss:0.5928  g_loss:1.7071
# epoch:598  d_loss:0.5563  g_loss:1.4519
# epoch:599  d_loss:0.5060  g_loss:1.4573
# epoch:600  d_loss:0.3892  g_loss:2.3021
# epoch:601  d_loss:0.2992  g_loss:1.7425
# epoch:602  d_loss:0.3375  g_loss:2.4373
# epoch:603  d_loss:0.5313  g_loss:2.1604
# epoch:604  d_loss:0.3438  g_loss:1.8466
# epoch:605  d_loss:0.2972  g_loss:1.7003
# epoch:606  d_loss:0.3044  g_loss:2.2373
# epoch:607  d_loss:0.3574  g_loss:1.9379
# epoch:608  d_loss:0.3798  g_loss:1.6217
# epoch:609  d_loss:0.4642  g_loss:1.8719
# epoch:610  d_loss:0.5773  g_loss:0.7900
# epoch:611  d_loss:0.6561  g_loss:0.7818
# epoch:612  d_loss:0.4307  g_loss:1.2413
# epoch:613  d_loss:0.7525  g_loss:1.0996
# epoch:614  d_loss:0.6965  g_loss:1.0011
# epoch:615  d_loss:0.4790  g_loss:1.4803
# epoch:616  d_loss:0.4782  g_loss:1.7955
# epoch:617  d_loss:0.5446  g_loss:1.2081
# epoch:618  d_loss:0.4074  g_loss:1.4930
# epoch:619  d_loss:0.3027  g_loss:1.3929
# epoch:620  d_loss:0.5098  g_loss:1.2216
# epoch:621  d_loss:0.6372  g_loss:1.2174
# epoch:622  d_loss:0.3252  g_loss:1.5409
# epoch:623  d_loss:0.5877  g_loss:1.5619
# epoch:624  d_loss:0.4494  g_loss:1.5497
# epoch:625  d_loss:1.1849  g_loss:0.8537
# epoch:626  d_loss:0.9547  g_loss:0.5334
# epoch:627  d_loss:0.7457  g_loss:1.0161
# epoch:628  d_loss:0.7557  g_loss:0.7468
# epoch:629  d_loss:0.5582  g_loss:1.0295
# epoch:630  d_loss:0.5966  g_loss:0.8889
# epoch:631  d_loss:0.4668  g_loss:1.4278
# epoch:632  d_loss:0.6014  g_loss:0.9894
# epoch:633  d_loss:0.6377  g_loss:0.7787
# epoch:634  d_loss:0.7402  g_loss:0.5390
# epoch:635  d_loss:0.7622  g_loss:0.4816
# epoch:636  d_loss:0.8841  g_loss:0.4733
# epoch:637  d_loss:0.9852  g_loss:0.5609
# epoch:638  d_loss:0.9089  g_loss:0.6780
# epoch:639  d_loss:0.9927  g_loss:0.6821
# epoch:640  d_loss:1.0749  g_loss:0.6899
# epoch:641  d_loss:0.8831  g_loss:0.5549
# epoch:642  d_loss:0.7926  g_loss:0.7224
# epoch:643  d_loss:0.7755  g_loss:0.8777
# epoch:644  d_loss:0.6789  g_loss:1.1464
# epoch:645  d_loss:0.7029  g_loss:1.1454
# epoch:646  d_loss:0.4958  g_loss:1.4516
# epoch:647  d_loss:0.5452  g_loss:1.4821
# epoch:648  d_loss:0.7616  g_loss:1.7071
# epoch:649  d_loss:0.7135  g_loss:1.4970
# epoch:650  d_loss:0.8737  g_loss:1.3613
# epoch:651  d_loss:1.0489  g_loss:1.1633
# epoch:652  d_loss:0.7120  g_loss:1.0789
# epoch:653  d_loss:0.6069  g_loss:1.2738
# epoch:654  d_loss:0.5912  g_loss:1.3108
# epoch:655  d_loss:0.3769  g_loss:1.7985
# epoch:656  d_loss:0.3976  g_loss:2.2069
# epoch:657  d_loss:0.4048  g_loss:2.5422
# epoch:658  d_loss:0.3122  g_loss:2.9758
# epoch:659  d_loss:0.2931  g_loss:2.7142
# epoch:660  d_loss:0.3341  g_loss:2.5773
# epoch:661  d_loss:0.3510  g_loss:3.0261
# epoch:662  d_loss:0.3209  g_loss:3.0867
# epoch:663  d_loss:0.3294  g_loss:2.5579
# epoch:664  d_loss:0.3783  g_loss:2.5275
# epoch:665  d_loss:0.6160  g_loss:2.3594
# epoch:666  d_loss:0.2645  g_loss:2.3460
# epoch:667  d_loss:0.3526  g_loss:2.1951
# epoch:668  d_loss:0.3674  g_loss:1.8268
# epoch:669  d_loss:0.3764  g_loss:1.7757
# epoch:670  d_loss:0.3888  g_loss:2.0634
# epoch:671  d_loss:0.3258  g_loss:2.3990
# epoch:672  d_loss:0.5584  g_loss:2.0810
# epoch:673  d_loss:0.4511  g_loss:1.7412
# epoch:674  d_loss:0.4286  g_loss:1.8112
# epoch:675  d_loss:0.3810  g_loss:2.0411
# epoch:676  d_loss:0.4042  g_loss:2.2280
# epoch:677  d_loss:0.4672  g_loss:1.9269
# epoch:678  d_loss:0.4733  g_loss:1.7733
# epoch:679  d_loss:0.3842  g_loss:2.1784
# epoch:680  d_loss:0.5376  g_loss:1.8478
# epoch:681  d_loss:0.7321  g_loss:1.9127
# epoch:682  d_loss:0.2867  g_loss:2.1386
# epoch:683  d_loss:0.3815  g_loss:2.3664
# epoch:684  d_loss:0.2794  g_loss:2.4511
# epoch:685  d_loss:0.3236  g_loss:2.7327
# epoch:686  d_loss:0.2322  g_loss:2.9742
# epoch:687  d_loss:0.2096  g_loss:3.4804
# epoch:688  d_loss:0.1615  g_loss:3.2825
# epoch:689  d_loss:0.1871  g_loss:3.1076
# epoch:690  d_loss:0.3823  g_loss:2.1078
# epoch:691  d_loss:0.5245  g_loss:1.5458
# epoch:692  d_loss:0.3092  g_loss:1.5362
# epoch:693  d_loss:0.4113  g_loss:1.6158
# epoch:694  d_loss:0.4572  g_loss:2.3143
# epoch:695  d_loss:0.4961  g_loss:2.4583
# epoch:696  d_loss:0.7341  g_loss:1.9742
# epoch:697  d_loss:0.7593  g_loss:1.5972
# epoch:698  d_loss:0.5385  g_loss:1.3923
# epoch:699  d_loss:0.6290  g_loss:1.5089
# epoch:700  d_loss:0.5460  g_loss:1.8906
# epoch:701  d_loss:0.7669  g_loss:2.0153
# epoch:702  d_loss:0.4773  g_loss:2.2647
# epoch:703  d_loss:0.7208  g_loss:2.1437
# epoch:704  d_loss:0.5383  g_loss:1.8961
# epoch:705  d_loss:0.4984  g_loss:1.6737
# epoch:706  d_loss:0.6098  g_loss:1.2296
# epoch:707  d_loss:0.7005  g_loss:1.4351
# epoch:708  d_loss:0.7343  g_loss:1.4801
# epoch:709  d_loss:0.3398  g_loss:2.2267
# epoch:710  d_loss:0.4270  g_loss:2.6803
# epoch:711  d_loss:0.5280  g_loss:2.5959
# epoch:712  d_loss:0.4407  g_loss:2.2507
# epoch:713  d_loss:0.3750  g_loss:1.8848
# epoch:714  d_loss:0.3830  g_loss:1.7270
# epoch:715  d_loss:0.4719  g_loss:1.8116
# epoch:716  d_loss:0.3951  g_loss:1.8679
# epoch:717  d_loss:0.4849  g_loss:2.1246
# epoch:718  d_loss:0.2292  g_loss:2.3511
# epoch:719  d_loss:0.3640  g_loss:1.9409
# epoch:720  d_loss:0.2779  g_loss:2.0785
# epoch:721  d_loss:0.3471  g_loss:2.1443
# epoch:722  d_loss:0.4353  g_loss:1.7654
# epoch:723  d_loss:0.3404  g_loss:1.5594
# epoch:724  d_loss:0.5192  g_loss:1.5274
# epoch:725  d_loss:0.4782  g_loss:2.1894
# epoch:726  d_loss:0.3419  g_loss:2.0198
# epoch:727  d_loss:0.3964  g_loss:1.9626
# epoch:728  d_loss:0.3103  g_loss:1.9201
# epoch:729  d_loss:0.3924  g_loss:2.1079
# epoch:730  d_loss:0.4189  g_loss:1.8744
# epoch:731  d_loss:0.4362  g_loss:1.5374
# epoch:732  d_loss:0.3227  g_loss:2.1787
# epoch:733  d_loss:0.3545  g_loss:2.1334
# epoch:734  d_loss:0.2964  g_loss:1.9865
# epoch:735  d_loss:0.3047  g_loss:1.9783
# epoch:736  d_loss:0.3456  g_loss:1.8846
# epoch:737  d_loss:0.3931  g_loss:1.9305
# epoch:738  d_loss:0.3747  g_loss:1.7794
# epoch:739  d_loss:0.4087  g_loss:1.7239
# epoch:740  d_loss:0.5742  g_loss:1.6274
# epoch:741  d_loss:0.5446  g_loss:1.5738
# epoch:742  d_loss:0.4982  g_loss:2.2879
# epoch:743  d_loss:0.4240  g_loss:2.0282
# epoch:744  d_loss:0.4433  g_loss:2.3543
# epoch:745  d_loss:0.3347  g_loss:1.9756
# epoch:746  d_loss:0.4813  g_loss:1.6324
# epoch:747  d_loss:0.3816  g_loss:1.2816
# epoch:748  d_loss:0.3328  g_loss:1.7806
# epoch:749  d_loss:0.3590  g_loss:2.0293
# epoch:750  d_loss:0.5198  g_loss:1.7741
# epoch:751  d_loss:0.5738  g_loss:1.5770
# epoch:752  d_loss:0.4065  g_loss:1.8809
# epoch:753  d_loss:0.4961  g_loss:1.5951
# epoch:754  d_loss:0.2803  g_loss:1.9873
# epoch:755  d_loss:0.3347  g_loss:1.7808
# epoch:756  d_loss:0.3703  g_loss:2.0635
# epoch:757  d_loss:0.3620  g_loss:1.9266
# epoch:758  d_loss:0.3604  g_loss:1.8006
# epoch:759  d_loss:0.3084  g_loss:1.9421
# epoch:760  d_loss:0.4471  g_loss:1.9156
# epoch:761  d_loss:0.4023  g_loss:1.6741
# epoch:762  d_loss:0.3968  g_loss:2.1306
# epoch:763  d_loss:0.3532  g_loss:2.1417
# epoch:764  d_loss:0.4474  g_loss:1.7058
# epoch:765  d_loss:0.4547  g_loss:1.8133
# epoch:766  d_loss:0.4005  g_loss:1.6108
# epoch:767  d_loss:0.4785  g_loss:1.5736
# epoch:768  d_loss:0.3979  g_loss:1.7233
# epoch:769  d_loss:0.4118  g_loss:1.9803
# epoch:770  d_loss:0.4935  g_loss:1.8730
# epoch:771  d_loss:0.4416  g_loss:1.6298
# epoch:772  d_loss:0.3973  g_loss:1.4579
# epoch:773  d_loss:0.5475  g_loss:1.6573
# epoch:774  d_loss:0.4385  g_loss:1.6484
# epoch:775  d_loss:0.3707  g_loss:1.6934
# epoch:776  d_loss:0.3971  g_loss:2.1292
# epoch:777  d_loss:0.5665  g_loss:1.8872
# epoch:778  d_loss:0.4421  g_loss:1.6158
# epoch:779  d_loss:0.4045  g_loss:1.5558
# epoch:780  d_loss:0.4791  g_loss:1.2362
# epoch:781  d_loss:0.5728  g_loss:1.0721
# epoch:782  d_loss:0.5418  g_loss:1.3427
# epoch:783  d_loss:0.5182  g_loss:1.2937
# epoch:784  d_loss:0.5107  g_loss:1.5268
# epoch:785  d_loss:0.5146  g_loss:1.4921
# epoch:786  d_loss:0.5661  g_loss:1.7912
# epoch:787  d_loss:0.5496  g_loss:1.7306
# epoch:788  d_loss:0.5367  g_loss:1.6902
# epoch:789  d_loss:0.3993  g_loss:1.3597
# epoch:790  d_loss:0.4750  g_loss:1.6943
# epoch:791  d_loss:0.4870  g_loss:1.5403
# epoch:792  d_loss:0.4743  g_loss:1.5043
# epoch:793  d_loss:0.6113  g_loss:1.7202
# epoch:794  d_loss:0.4086  g_loss:1.3689
# epoch:795  d_loss:0.5083  g_loss:1.4400
# epoch:796  d_loss:0.5095  g_loss:1.5129
# epoch:797  d_loss:0.3949  g_loss:1.8614
# epoch:798  d_loss:0.6573  g_loss:1.3399
# epoch:799  d_loss:0.5738  g_loss:1.4245
# epoch:800  d_loss:0.4531  g_loss:1.4433
# epoch:801  d_loss:0.4699  g_loss:1.5377
# epoch:802  d_loss:0.5553  g_loss:1.4904
# epoch:803  d_loss:0.5272  g_loss:1.2923
# epoch:804  d_loss:0.5142  g_loss:1.4634
# epoch:805  d_loss:0.5065  g_loss:1.4685
# epoch:806  d_loss:0.5664  g_loss:1.4089
# epoch:807  d_loss:0.4587  g_loss:1.4835
# epoch:808  d_loss:0.4152  g_loss:1.6176
# epoch:809  d_loss:0.3937  g_loss:1.5700
# epoch:810  d_loss:0.3773  g_loss:1.8553
# epoch:811  d_loss:0.2979  g_loss:1.7133
# epoch:812  d_loss:0.4158  g_loss:1.9846
# epoch:813  d_loss:0.4429  g_loss:1.4090
# epoch:814  d_loss:0.5233  g_loss:1.3641
# epoch:815  d_loss:0.4750  g_loss:1.3610
# epoch:816  d_loss:0.4964  g_loss:1.4050
# epoch:817  d_loss:0.3801  g_loss:1.7803
# epoch:818  d_loss:0.3997  g_loss:1.9821
# epoch:819  d_loss:0.4699  g_loss:2.0509
# epoch:820  d_loss:0.4806  g_loss:1.7767
# epoch:821  d_loss:0.5287  g_loss:1.2772
# epoch:822  d_loss:0.5460  g_loss:1.1130
# epoch:823  d_loss:0.5674  g_loss:1.6005
# epoch:824  d_loss:0.5730  g_loss:1.4189
# epoch:825  d_loss:0.6301  g_loss:1.2524
# epoch:826  d_loss:0.7227  g_loss:1.1958
# epoch:827  d_loss:0.7404  g_loss:0.9225
# epoch:828  d_loss:0.5557  g_loss:1.0214
# epoch:829  d_loss:0.5961  g_loss:1.3320
# epoch:830  d_loss:0.5463  g_loss:1.2639
# epoch:831  d_loss:0.7356  g_loss:1.1043
# epoch:832  d_loss:0.5142  g_loss:1.0395
# epoch:833  d_loss:0.5245  g_loss:1.1658
# epoch:834  d_loss:0.7614  g_loss:1.1758
# epoch:835  d_loss:0.6208  g_loss:1.1447
# epoch:836  d_loss:0.6258  g_loss:1.3251
# epoch:837  d_loss:0.5811  g_loss:1.3583
# epoch:838  d_loss:0.4146  g_loss:1.3536
# epoch:839  d_loss:0.5380  g_loss:1.3912
# epoch:840  d_loss:0.3772  g_loss:1.4270
# epoch:841  d_loss:0.5777  g_loss:1.3913
# epoch:842  d_loss:0.4318  g_loss:1.4432
# epoch:843  d_loss:0.4543  g_loss:1.6961
# epoch:844  d_loss:0.5284  g_loss:1.5794
# epoch:845  d_loss:0.4153  g_loss:1.7422
# epoch:846  d_loss:0.4614  g_loss:1.8158
# epoch:847  d_loss:0.5159  g_loss:1.7645
# epoch:848  d_loss:0.4811  g_loss:1.6338
# epoch:849  d_loss:0.3965  g_loss:1.4094
# epoch:850  d_loss:0.4641  g_loss:1.2711
# epoch:851  d_loss:0.3929  g_loss:1.6897
# epoch:852  d_loss:0.4643  g_loss:1.5919
# epoch:853  d_loss:0.4975  g_loss:1.7992
# epoch:854  d_loss:0.4632  g_loss:1.5343
# epoch:855  d_loss:0.3994  g_loss:1.7067
# epoch:856  d_loss:0.4810  g_loss:1.8137
# epoch:857  d_loss:0.3994  g_loss:1.6912
# epoch:858  d_loss:0.4891  g_loss:1.5617
# epoch:859  d_loss:0.6672  g_loss:1.3362
# epoch:860  d_loss:0.5772  g_loss:1.1151
# epoch:861  d_loss:0.4847  g_loss:1.2781
# epoch:862  d_loss:0.5827  g_loss:1.4021
# epoch:863  d_loss:0.3525  g_loss:1.9135
# epoch:864  d_loss:0.3623  g_loss:1.9992
# epoch:865  d_loss:0.3719  g_loss:1.7323
# epoch:866  d_loss:0.4839  g_loss:1.8903
# epoch:867  d_loss:0.4124  g_loss:1.5172
# epoch:868  d_loss:0.4047  g_loss:1.4267
# epoch:869  d_loss:0.3484  g_loss:1.2318
# epoch:870  d_loss:0.3759  g_loss:1.6063
# epoch:871  d_loss:0.3436  g_loss:1.7752
# epoch:872  d_loss:0.4628  g_loss:1.8418
# epoch:873  d_loss:0.4509  g_loss:1.7127
# epoch:874  d_loss:0.4029  g_loss:2.0006
# epoch:875  d_loss:0.3776  g_loss:2.0569
# epoch:876  d_loss:0.4527  g_loss:1.8616
# epoch:877  d_loss:0.4449  g_loss:1.7567
# epoch:878  d_loss:0.3625  g_loss:2.0752
# epoch:879  d_loss:0.5005  g_loss:1.9792
# epoch:880  d_loss:0.3709  g_loss:2.0969
# epoch:881  d_loss:0.4122  g_loss:2.1525
# epoch:882  d_loss:0.2541  g_loss:2.1523
# epoch:883  d_loss:0.3045  g_loss:2.3432
# epoch:884  d_loss:0.4886  g_loss:1.6875
# epoch:885  d_loss:0.3199  g_loss:1.6999
# epoch:886  d_loss:0.5039  g_loss:1.3261
# epoch:887  d_loss:0.5034  g_loss:1.6797
# epoch:888  d_loss:0.3919  g_loss:2.3415
# epoch:889  d_loss:0.4320  g_loss:1.9212
# epoch:890  d_loss:0.5841  g_loss:1.8166
# epoch:891  d_loss:0.5099  g_loss:1.5400
# epoch:892  d_loss:0.4959  g_loss:1.5541
# epoch:893  d_loss:0.5232  g_loss:1.3316
# epoch:894  d_loss:0.4027  g_loss:1.4732
# epoch:895  d_loss:0.5568  g_loss:1.2545
# epoch:896  d_loss:0.3888  g_loss:1.8901
# epoch:897  d_loss:0.4510  g_loss:1.7412
# epoch:898  d_loss:0.4854  g_loss:1.5848
# epoch:899  d_loss:0.5558  g_loss:1.3301
# epoch:900  d_loss:0.4162  g_loss:1.2784
# epoch:901  d_loss:0.6037  g_loss:1.5452
# epoch:902  d_loss:0.5878  g_loss:1.6157
# epoch:903  d_loss:0.5582  g_loss:1.7003
# epoch:904  d_loss:0.5544  g_loss:1.5192
# epoch:905  d_loss:0.4132  g_loss:1.7816
# epoch:906  d_loss:0.5271  g_loss:1.4507
# epoch:907  d_loss:0.5056  g_loss:1.8651
# epoch:908  d_loss:0.4443  g_loss:1.6249
# epoch:909  d_loss:0.4580  g_loss:1.7309
# epoch:910  d_loss:0.4158  g_loss:1.9985
# epoch:911  d_loss:0.3902  g_loss:2.0795
# epoch:912  d_loss:0.3850  g_loss:2.2070
# epoch:913  d_loss:0.3818  g_loss:2.0752
# epoch:914  d_loss:0.4031  g_loss:1.9499
# epoch:915  d_loss:0.3415  g_loss:1.6057
# epoch:916  d_loss:0.4246  g_loss:1.7567
# epoch:917  d_loss:0.5193  g_loss:1.9276
# epoch:918  d_loss:0.4391  g_loss:2.0724
# epoch:919  d_loss:0.4340  g_loss:1.7980
# epoch:920  d_loss:0.3713  g_loss:1.7781
# epoch:921  d_loss:0.6965  g_loss:1.3780
# epoch:922  d_loss:0.5163  g_loss:1.6789
# epoch:923  d_loss:0.6014  g_loss:1.5926
# epoch:924  d_loss:0.6823  g_loss:1.5040
# epoch:925  d_loss:0.7631  g_loss:1.4138
# epoch:926  d_loss:0.5455  g_loss:1.3245
# epoch:927  d_loss:0.5795  g_loss:1.5459
# epoch:928  d_loss:0.5237  g_loss:1.3609
# epoch:929  d_loss:0.5324  g_loss:1.3441
# epoch:930  d_loss:0.5619  g_loss:1.4859
# epoch:931  d_loss:0.5319  g_loss:1.4877
# epoch:932  d_loss:0.4417  g_loss:1.9343
# epoch:933  d_loss:0.5025  g_loss:1.8965
# epoch:934  d_loss:0.4986  g_loss:1.5044
# epoch:935  d_loss:0.3864  g_loss:1.3439
# epoch:936  d_loss:0.5368  g_loss:1.8509
# epoch:937  d_loss:0.3120  g_loss:2.1042
# epoch:938  d_loss:0.4316  g_loss:2.3160
# epoch:939  d_loss:0.3239  g_loss:2.1086
# epoch:940  d_loss:0.3162  g_loss:2.0057
# epoch:941  d_loss:0.3315  g_loss:2.3129
# epoch:942  d_loss:0.3077  g_loss:2.6675
# epoch:943  d_loss:0.2793  g_loss:2.6226
# epoch:944  d_loss:0.2449  g_loss:2.4796
# epoch:945  d_loss:0.2911  g_loss:2.4856
# epoch:946  d_loss:0.2916  g_loss:2.0453
# epoch:947  d_loss:0.3037  g_loss:2.4557
# epoch:948  d_loss:0.3896  g_loss:2.5546
# epoch:949  d_loss:0.1892  g_loss:2.9137
# epoch:950  d_loss:0.3340  g_loss:2.5023
# epoch:951  d_loss:0.2853  g_loss:2.3973
# epoch:952  d_loss:0.4635  g_loss:1.9112
# epoch:953  d_loss:0.5114  g_loss:2.3175
# epoch:954  d_loss:0.4230  g_loss:2.2802
# epoch:955  d_loss:0.5219  g_loss:2.2052
# epoch:956  d_loss:0.4871  g_loss:2.3516
# epoch:957  d_loss:0.5385  g_loss:1.5789
# epoch:958  d_loss:0.5502  g_loss:1.7520
# epoch:959  d_loss:0.5159  g_loss:1.3696
# epoch:960  d_loss:0.6392  g_loss:1.6605
# epoch:961  d_loss:0.5978  g_loss:1.6449
# epoch:962  d_loss:0.7258  g_loss:2.2080
# epoch:963  d_loss:0.7494  g_loss:1.5728
# epoch:964  d_loss:0.7185  g_loss:1.4219
# epoch:965  d_loss:0.7524  g_loss:1.6998
# epoch:966  d_loss:0.6769  g_loss:1.1959
# epoch:967  d_loss:0.6865  g_loss:1.0112
# epoch:968  d_loss:0.5923  g_loss:1.4054
# epoch:969  d_loss:0.6259  g_loss:1.6247
# epoch:970  d_loss:0.5665  g_loss:1.9191
# epoch:971  d_loss:0.7177  g_loss:1.5258
# epoch:972  d_loss:0.4775  g_loss:1.5419
# epoch:973  d_loss:0.4952  g_loss:1.3869
# epoch:974  d_loss:0.4681  g_loss:1.4524
# epoch:975  d_loss:0.3953  g_loss:1.8422
# epoch:976  d_loss:0.3866  g_loss:1.8952
# epoch:977  d_loss:0.3958  g_loss:1.7658
# epoch:978  d_loss:0.3929  g_loss:2.0888
# epoch:979  d_loss:0.3628  g_loss:1.9702
# epoch:980  d_loss:0.3850  g_loss:1.7550
# epoch:981  d_loss:0.3678  g_loss:2.2838
# epoch:982  d_loss:0.3586  g_loss:2.2294
# epoch:983  d_loss:0.3740  g_loss:1.9805
# epoch:984  d_loss:0.3680  g_loss:2.4101
# epoch:985  d_loss:0.3005  g_loss:2.2441
# epoch:986  d_loss:0.3626  g_loss:2.0745
# epoch:987  d_loss:0.3178  g_loss:2.3885
# epoch:988  d_loss:0.3056  g_loss:2.2869
# epoch:989  d_loss:0.5019  g_loss:1.5255
# epoch:990  d_loss:0.5374  g_loss:1.5318
# epoch:991  d_loss:0.3174  g_loss:1.9137
# epoch:992  d_loss:0.5467  g_loss:1.9179
# epoch:993  d_loss:0.5525  g_loss:1.8493
# epoch:994  d_loss:0.3908  g_loss:2.0985
# epoch:995  d_loss:0.5688  g_loss:1.7340
# epoch:996  d_loss:0.6049  g_loss:1.3758
# epoch:997  d_loss:0.5489  g_loss:1.6246
# epoch:998  d_loss:0.6360  g_loss:1.5828
# epoch:999  d_loss:0.4224  g_loss:1.6804
# epoch:1000  d_loss:0.6145  g_loss:1.7566
# epoch:1001  d_loss:0.5230  g_loss:1.9044
# epoch:1002  d_loss:0.4428  g_loss:1.8107
# epoch:1003  d_loss:0.7162  g_loss:2.0117
# epoch:1004  d_loss:0.4928  g_loss:1.9539
# epoch:1005  d_loss:0.4866  g_loss:2.0420
# epoch:1006  d_loss:0.4476  g_loss:1.9844
# epoch:1007  d_loss:0.4955  g_loss:1.9261
# epoch:1008  d_loss:0.3184  g_loss:1.9860
# epoch:1009  d_loss:0.3193  g_loss:1.8538
# epoch:1010  d_loss:0.3158  g_loss:1.9106
# epoch:1011  d_loss:0.3820  g_loss:1.6952
# epoch:1012  d_loss:0.3257  g_loss:2.3203
# epoch:1013  d_loss:0.2319  g_loss:2.3059
# epoch:1014  d_loss:0.2167  g_loss:2.6508
# epoch:1015  d_loss:0.3828  g_loss:2.1550
# epoch:1016  d_loss:0.3450  g_loss:2.3188
# epoch:1017  d_loss:0.3914  g_loss:2.2771
# epoch:1018  d_loss:0.3306  g_loss:2.2237
# epoch:1019  d_loss:0.3109  g_loss:2.7405
# epoch:1020  d_loss:0.3675  g_loss:3.0473
# epoch:1021  d_loss:0.1888  g_loss:2.7795
# epoch:1022  d_loss:0.3435  g_loss:2.8121
# epoch:1023  d_loss:0.4029  g_loss:2.4717
# epoch:1024  d_loss:0.3859  g_loss:2.1904
# epoch:1025  d_loss:0.4651  g_loss:1.6157
# epoch:1026  d_loss:0.5180  g_loss:1.8054
# epoch:1027  d_loss:0.5289  g_loss:1.7909
# epoch:1028  d_loss:0.4391  g_loss:2.2595
# epoch:1029  d_loss:0.3725  g_loss:2.8099
# epoch:1030  d_loss:0.5782  g_loss:1.9938
# epoch:1031  d_loss:0.6457  g_loss:1.8501
# epoch:1032  d_loss:0.7465  g_loss:1.5668
# epoch:1033  d_loss:0.5882  g_loss:1.7409
# epoch:1034  d_loss:0.4584  g_loss:1.8530
# epoch:1035  d_loss:0.4892  g_loss:1.8815
# epoch:1036  d_loss:0.7049  g_loss:1.6268
# epoch:1037  d_loss:0.6141  g_loss:1.8228
# epoch:1038  d_loss:0.4420  g_loss:1.9822
# epoch:1039  d_loss:0.4280  g_loss:1.8621
# epoch:1040  d_loss:0.6807  g_loss:1.8823
# epoch:1041  d_loss:0.4957  g_loss:1.3486
# epoch:1042  d_loss:0.6586  g_loss:1.7080
# epoch:1043  d_loss:0.4830  g_loss:2.0921
# epoch:1044  d_loss:0.5265  g_loss:1.7745
# epoch:1045  d_loss:0.5561  g_loss:1.8866
# epoch:1046  d_loss:0.3652  g_loss:1.9726
# epoch:1047  d_loss:0.4469  g_loss:1.5135
# epoch:1048  d_loss:0.4818  g_loss:1.7251
# epoch:1049  d_loss:0.4874  g_loss:1.9937
# epoch:1050  d_loss:0.4943  g_loss:1.9839
# epoch:1051  d_loss:0.4831  g_loss:1.7999
# epoch:1052  d_loss:0.3974  g_loss:2.0907
# epoch:1053  d_loss:0.3960  g_loss:2.0604
# epoch:1054  d_loss:0.2422  g_loss:2.0708
# epoch:1055  d_loss:0.4114  g_loss:1.9688
# epoch:1056  d_loss:0.3317  g_loss:1.8884
# epoch:1057  d_loss:0.3961  g_loss:1.8508
# epoch:1058  d_loss:0.3908  g_loss:1.8652
# epoch:1059  d_loss:0.3424  g_loss:1.9665
# epoch:1060  d_loss:0.3508  g_loss:2.0542
# epoch:1061  d_loss:0.3075  g_loss:2.4897
# epoch:1062  d_loss:0.3718  g_loss:2.1121
# epoch:1063  d_loss:0.4626  g_loss:2.2529
# epoch:1064  d_loss:0.4837  g_loss:1.3756
# epoch:1065  d_loss:0.3370  g_loss:1.5435
# epoch:1066  d_loss:0.4272  g_loss:1.6937
# epoch:1067  d_loss:0.4289  g_loss:2.1558
# epoch:1068  d_loss:0.4457  g_loss:2.3216
# epoch:1069  d_loss:0.3916  g_loss:2.0815
# epoch:1070  d_loss:0.3927  g_loss:1.8014
# epoch:1071  d_loss:0.3746  g_loss:1.5821
# epoch:1072  d_loss:0.4914  g_loss:1.7988
# epoch:1073  d_loss:0.4143  g_loss:1.5670
# epoch:1074  d_loss:0.3681  g_loss:1.8502
# epoch:1075  d_loss:0.5137  g_loss:2.0099
# epoch:1076  d_loss:0.4864  g_loss:1.9419
# epoch:1077  d_loss:0.3855  g_loss:2.0037
# epoch:1078  d_loss:0.3969  g_loss:2.6757
# epoch:1079  d_loss:0.3981  g_loss:2.5238
# epoch:1080  d_loss:0.4310  g_loss:2.0286
# epoch:1081  d_loss:0.3726  g_loss:1.6645
# epoch:1082  d_loss:0.3716  g_loss:1.7463
# epoch:1083  d_loss:0.3813  g_loss:2.4672
# epoch:1084  d_loss:0.2878  g_loss:2.3331
# epoch:1085  d_loss:0.3486  g_loss:2.5109
# epoch:1086  d_loss:0.3542  g_loss:2.5896
# epoch:1087  d_loss:0.3264  g_loss:2.2597
# epoch:1088  d_loss:0.3799  g_loss:2.2117
# epoch:1089  d_loss:0.3502  g_loss:1.9309
# epoch:1090  d_loss:0.3040  g_loss:1.8247
# epoch:1091  d_loss:0.3552  g_loss:2.0631
# epoch:1092  d_loss:0.3187  g_loss:2.3096
# epoch:1093  d_loss:0.3299  g_loss:2.2479
# epoch:1094  d_loss:0.4425  g_loss:2.4172
# epoch:1095  d_loss:0.5589  g_loss:1.9660
# epoch:1096  d_loss:0.4299  g_loss:1.7296
# epoch:1097  d_loss:0.4924  g_loss:2.0610
# epoch:1098  d_loss:0.5147  g_loss:1.9035
# epoch:1099  d_loss:0.4741  g_loss:2.1584
# epoch:1100  d_loss:0.5612  g_loss:1.7173
# epoch:1101  d_loss:0.4437  g_loss:1.9108
# epoch:1102  d_loss:0.3876  g_loss:1.4501
# epoch:1103  d_loss:0.6837  g_loss:1.3879
# epoch:1104  d_loss:0.4228  g_loss:1.4718
# epoch:1105  d_loss:0.4290  g_loss:1.9710
# epoch:1106  d_loss:0.5762  g_loss:2.3781
# epoch:1107  d_loss:0.7214  g_loss:2.2282
# epoch:1108  d_loss:0.6668  g_loss:1.1234
# epoch:1109  d_loss:0.5954  g_loss:1.3363
# epoch:1110  d_loss:0.5792  g_loss:1.3268
# epoch:1111  d_loss:0.4506  g_loss:1.8020
# epoch:1112  d_loss:0.4619  g_loss:2.2192
# epoch:1113  d_loss:0.6012  g_loss:1.9251
# epoch:1114  d_loss:0.4024  g_loss:2.2666
# epoch:1115  d_loss:0.5172  g_loss:1.4767
# epoch:1116  d_loss:0.6420  g_loss:1.2903
# epoch:1117  d_loss:0.3698  g_loss:1.7274
# epoch:1118  d_loss:0.5258  g_loss:1.6135
# epoch:1119  d_loss:0.4732  g_loss:1.8720
# epoch:1120  d_loss:0.4133  g_loss:1.8340
# epoch:1121  d_loss:0.3542  g_loss:1.8837
# epoch:1122  d_loss:0.3286  g_loss:1.6531
# epoch:1123  d_loss:0.3012  g_loss:1.8597
# epoch:1124  d_loss:0.3545  g_loss:1.8126
# epoch:1125  d_loss:0.4273  g_loss:1.6126
# epoch:1126  d_loss:0.3404  g_loss:2.0614
# epoch:1127  d_loss:0.2946  g_loss:1.8412
# epoch:1128  d_loss:0.3297  g_loss:2.0172
# epoch:1129  d_loss:0.4180  g_loss:2.1660
# epoch:1130  d_loss:0.3714  g_loss:2.0431
# epoch:1131  d_loss:0.4269  g_loss:1.5984
# epoch:1132  d_loss:0.3892  g_loss:2.0144
# epoch:1133  d_loss:0.3754  g_loss:1.8758
# epoch:1134  d_loss:0.3416  g_loss:1.9274
# epoch:1135  d_loss:0.5088  g_loss:1.6479
# epoch:1136  d_loss:0.3888  g_loss:2.0754
# epoch:1137  d_loss:0.3842  g_loss:1.7464
# epoch:1138  d_loss:0.4079  g_loss:2.1252
# epoch:1139  d_loss:0.4803  g_loss:1.9373
# epoch:1140  d_loss:0.4877  g_loss:1.7870
# epoch:1141  d_loss:0.5344  g_loss:1.3015
# epoch:1142  d_loss:0.4129  g_loss:1.6864
# epoch:1143  d_loss:0.3779  g_loss:1.8395
# epoch:1144  d_loss:0.3927  g_loss:1.4532
# epoch:1145  d_loss:0.5348  g_loss:1.6355
# epoch:1146  d_loss:0.4053  g_loss:1.4383
# epoch:1147  d_loss:0.4376  g_loss:1.7810
# epoch:1148  d_loss:0.4558  g_loss:1.4736
# epoch:1149  d_loss:0.4653  g_loss:1.4785
# epoch:1150  d_loss:0.3877  g_loss:1.6711
# epoch:1151  d_loss:0.3521  g_loss:1.6457
# epoch:1152  d_loss:0.3985  g_loss:1.8137
# epoch:1153  d_loss:0.4280  g_loss:1.8340
# epoch:1154  d_loss:0.3806  g_loss:1.7345
# epoch:1155  d_loss:0.4805  g_loss:1.5959
# epoch:1156  d_loss:0.4818  g_loss:1.8078
# epoch:1157  d_loss:0.5141  g_loss:1.5995
# epoch:1158  d_loss:0.4939  g_loss:1.5697
# epoch:1159  d_loss:0.6585  g_loss:1.2531
# epoch:1160  d_loss:0.4033  g_loss:1.4552
# epoch:1161  d_loss:0.3938  g_loss:1.8426
# epoch:1162  d_loss:0.5989  g_loss:1.7161
# epoch:1163  d_loss:0.4842  g_loss:1.5377
# epoch:1164  d_loss:0.5046  g_loss:1.1300
# epoch:1165  d_loss:0.4655  g_loss:1.6419
# epoch:1166  d_loss:0.5149  g_loss:1.2623
# epoch:1167  d_loss:0.5433  g_loss:1.4309
# epoch:1168  d_loss:0.4041  g_loss:1.7720
# epoch:1169  d_loss:0.5265  g_loss:1.3950
# epoch:1170  d_loss:0.5702  g_loss:1.5331
# epoch:1171  d_loss:0.4003  g_loss:1.6543
# epoch:1172  d_loss:0.3502  g_loss:1.8637
# epoch:1173  d_loss:0.3021  g_loss:1.9448
# epoch:1174  d_loss:0.4045  g_loss:2.0565
# epoch:1175  d_loss:0.4087  g_loss:1.9902
# epoch:1176  d_loss:0.4716  g_loss:1.6466
# epoch:1177  d_loss:0.5024  g_loss:1.6052
# epoch:1178  d_loss:0.5021  g_loss:1.5329
# epoch:1179  d_loss:0.3168  g_loss:1.8221
# epoch:1180  d_loss:0.3533  g_loss:2.1677
# epoch:1181  d_loss:0.4348  g_loss:2.0830
# epoch:1182  d_loss:0.3547  g_loss:2.3591
# epoch:1183  d_loss:0.4959  g_loss:1.6759
# epoch:1184  d_loss:0.3286  g_loss:1.7130
# epoch:1185  d_loss:0.4638  g_loss:1.6389
# epoch:1186  d_loss:0.5040  g_loss:1.4363
# epoch:1187  d_loss:0.3625  g_loss:2.0385
# epoch:1188  d_loss:0.4096  g_loss:1.8695
# epoch:1189  d_loss:0.3302  g_loss:2.2608
# epoch:1190  d_loss:0.4130  g_loss:2.2582
# epoch:1191  d_loss:0.3727  g_loss:1.9735
# epoch:1192  d_loss:0.4810  g_loss:2.0132
# epoch:1193  d_loss:0.6149  g_loss:1.4163
# epoch:1194  d_loss:0.5688  g_loss:1.1701
# epoch:1195  d_loss:0.5174  g_loss:1.4133
# epoch:1196  d_loss:0.4840  g_loss:1.4606
# ...
# epoch:3620  d_loss:0.5504  g_loss:1.4185
# epoch:3621  d_loss:0.5067  g_loss:1.5075
# epoch:3622  d_loss:0.4690  g_loss:1.9214
# epoch:3623  d_loss:0.5610  g_loss:1.8520
# epoch:3624  d_loss:0.3631  g_loss:2.0403
# epoch:3625  d_loss:0.5053  g_loss:1.5872
# epoch:3626  d_loss:0.5918  g_loss:1.4530
# epoch:3627  d_loss:0.5564  g_loss:1.6886
# epoch:3628  d_loss:0.6983  g_loss:1.0760
# epoch:3629  d_loss:0.7803  g_loss:1.4690
# epoch:3630  d_loss:0.4473  g_loss:1.6574
# epoch:3631  d_loss:0.6217  g_loss:2.1265
# epoch:3632  d_loss:0.5162  g_loss:1.7158
# epoch:3633  d_loss:0.5458  g_loss:1.4900
# epoch:3634  d_loss:0.4731  g_loss:1.2342
# epoch:3635  d_loss:0.6454  g_loss:1.2287
# epoch:3636  d_loss:0.4915  g_loss:1.5038
# epoch:3637  d_loss:0.4733  g_loss:1.5856
# epoch:3638  d_loss:0.3763  g_loss:1.9198
# epoch:3639  d_loss:0.4485  g_loss:1.5591
# epoch:3640  d_loss:0.4744  g_loss:1.6785
# epoch:3641  d_loss:0.4226  g_loss:1.5636
# epoch:3642  d_loss:0.3958  g_loss:1.8837
# epoch:3643  d_loss:0.4494  g_loss:1.5471
# epoch:3644  d_loss:0.4621  g_loss:2.0758
# epoch:3645  d_loss:0.4071  g_loss:2.0109
# epoch:3646  d_loss:0.5074  g_loss:2.2855
# epoch:3647  d_loss:0.3744  g_loss:1.6785
# epoch:3648  d_loss:0.4399  g_loss:2.1336
# epoch:3649  d_loss:0.4186  g_loss:1.8767
# epoch:3650  d_loss:0.3675  g_loss:2.0973
# epoch:3651  d_loss:0.3923  g_loss:2.2718
# epoch:3652  d_loss:0.4744  g_loss:2.1112
# epoch:3653  d_loss:0.4105  g_loss:1.7377
# epoch:3654  d_loss:0.4519  g_loss:1.9658
# epoch:3655  d_loss:0.3878  g_loss:2.0264
# epoch:3656  d_loss:0.3343  g_loss:2.2829
# epoch:3657  d_loss:0.4259  g_loss:2.4727
# epoch:3658  d_loss:0.3529  g_loss:2.3001
# epoch:3659  d_loss:0.4773  g_loss:2.2395
# epoch:3660  d_loss:0.5511  g_loss:2.0369
# epoch:3661  d_loss:0.4470  g_loss:1.4915
# epoch:3662  d_loss:0.5334  g_loss:1.6190
# epoch:3663  d_loss:0.4284  g_loss:1.5639
# epoch:3664  d_loss:0.4749  g_loss:2.2511
# epoch:3665  d_loss:0.5675  g_loss:2.2283
# epoch:3666  d_loss:0.4915  g_loss:1.9131
# epoch:3667  d_loss:0.4584  g_loss:2.1433
# epoch:3668  d_loss:0.4831  g_loss:1.8081
# epoch:3669  d_loss:0.6645  g_loss:1.7633
# epoch:3670  d_loss:0.4328  g_loss:1.9201
# epoch:3671  d_loss:0.5578  g_loss:1.9707
# epoch:3672  d_loss:0.5640  g_loss:1.5611
# epoch:3673  d_loss:0.4548  g_loss:1.8371
# epoch:3674  d_loss:0.3747  g_loss:2.2045
# epoch:3675  d_loss:0.3628  g_loss:2.1948
# epoch:3676  d_loss:0.5118  g_loss:2.3523
# epoch:3677  d_loss:0.5545  g_loss:1.5350
# epoch:3678  d_loss:0.4212  g_loss:1.8422
# epoch:3679  d_loss:0.4092  g_loss:1.5325
# epoch:3680  d_loss:0.3960  g_loss:1.7034
# epoch:3681  d_loss:0.5001  g_loss:2.0094
# epoch:3682  d_loss:0.4058  g_loss:1.9209
# epoch:3683  d_loss:0.5139  g_loss:1.8287
# epoch:3684  d_loss:0.4117  g_loss:1.7661
# epoch:3685  d_loss:0.2967  g_loss:1.7342
# epoch:3686  d_loss:0.5718  g_loss:1.3055
# epoch:3687  d_loss:0.5788  g_loss:1.6314
# epoch:3688  d_loss:0.5323  g_loss:1.7793
# epoch:3689  d_loss:0.5448  g_loss:1.4835
# epoch:3690  d_loss:0.5101  g_loss:1.5970
# epoch:3691  d_loss:0.4660  g_loss:1.9695
# epoch:3692  d_loss:0.5381  g_loss:1.5592
# epoch:3693  d_loss:0.6024  g_loss:1.6629
# epoch:3694  d_loss:0.3487  g_loss:1.7846
# epoch:3695  d_loss:0.4648  g_loss:2.1782
# epoch:3696  d_loss:0.5157  g_loss:1.6501
# epoch:3697  d_loss:0.3981  g_loss:1.6792
# epoch:3698  d_loss:0.5285  g_loss:1.5841
# epoch:3699  d_loss:0.4690  g_loss:1.7632
# epoch:3700  d_loss:0.4466  g_loss:2.1138
# epoch:3701  d_loss:0.4607  g_loss:2.0700
# epoch:3702  d_loss:0.5570  g_loss:2.3807
# epoch:3703  d_loss:0.5655  g_loss:1.7760
# epoch:3704  d_loss:0.5909  g_loss:1.3482
# epoch:3705  d_loss:0.4859  g_loss:1.6959
# epoch:3706  d_loss:0.4827  g_loss:1.7125
# epoch:3707  d_loss:0.4029  g_loss:1.7741
# epoch:3708  d_loss:0.3477  g_loss:2.0661
# epoch:3709  d_loss:0.5303  g_loss:1.6639
# epoch:3710  d_loss:0.4477  g_loss:2.3195
# epoch:3711  d_loss:0.4023  g_loss:1.7371
# epoch:3712  d_loss:0.3494  g_loss:1.9883
# epoch:3713  d_loss:0.5283  g_loss:2.0743
# epoch:3714  d_loss:0.5410  g_loss:1.9947
# epoch:3715  d_loss:0.4583  g_loss:1.8821
# epoch:3716  d_loss:0.6102  g_loss:1.8889
# epoch:3717  d_loss:0.5119  g_loss:2.2951
# epoch:3718  d_loss:0.3171  g_loss:2.1658
# epoch:3719  d_loss:0.3531  g_loss:2.2829
# epoch:3720  d_loss:0.4545  g_loss:1.8624
# epoch:3721  d_loss:0.4288  g_loss:2.0606
# epoch:3722  d_loss:0.3739  g_loss:2.1313
# epoch:3723  d_loss:0.3426  g_loss:1.9682
# epoch:3724  d_loss:0.4980  g_loss:1.8979
# epoch:3725  d_loss:0.4794  g_loss:1.7886
# epoch:3726  d_loss:0.4539  g_loss:2.0433
# epoch:3727  d_loss:0.4455  g_loss:1.8005
# epoch:3728  d_loss:0.4826  g_loss:1.8292
# epoch:3729  d_loss:0.4219  g_loss:2.1161
# epoch:3730  d_loss:0.4100  g_loss:1.8571
# epoch:3731  d_loss:0.6593  g_loss:1.6028
# epoch:3732  d_loss:0.4872  g_loss:1.6698
# epoch:3733  d_loss:0.4790  g_loss:1.1928
# epoch:3734  d_loss:0.5457  g_loss:1.6961
# epoch:3735  d_loss:0.5372  g_loss:1.8382
# epoch:3736  d_loss:0.4868  g_loss:2.3269
# epoch:3737  d_loss:0.3404  g_loss:2.4569
# epoch:3738  d_loss:0.6225  g_loss:1.7166
# epoch:3739  d_loss:0.4811  g_loss:1.8702
# epoch:3740  d_loss:0.6145  g_loss:1.7113
# epoch:3741  d_loss:0.4894  g_loss:1.6257
# epoch:3742  d_loss:0.4627  g_loss:1.5248
# epoch:3743  d_loss:0.3599  g_loss:2.0940
# epoch:3744  d_loss:0.3522  g_loss:2.7306
# epoch:3745  d_loss:0.5090  g_loss:2.8148
# epoch:3746  d_loss:0.4946  g_loss:2.2603
# epoch:3747  d_loss:0.4115  g_loss:2.0793
# epoch:3748  d_loss:0.4528  g_loss:1.5170
# epoch:3749  d_loss:0.6315  g_loss:1.2569
# epoch:3750  d_loss:0.5579  g_loss:1.6914
# epoch:3751  d_loss:0.5286  g_loss:1.8215
# epoch:3752  d_loss:0.4305  g_loss:2.3859
# epoch:3753  d_loss:0.4712  g_loss:1.9709
# epoch:3754  d_loss:0.4957  g_loss:1.9215
# epoch:3755  d_loss:0.4970  g_loss:1.3311
# epoch:3756  d_loss:0.6054  g_loss:1.2998
# epoch:3757  d_loss:0.3245  g_loss:1.3682
# epoch:3758  d_loss:0.4350  g_loss:1.8973
# epoch:3759  d_loss:0.3711  g_loss:1.6239
# epoch:3760  d_loss:0.4583  g_loss:1.3338
# epoch:3761  d_loss:0.5649  g_loss:1.6298
# epoch:3762  d_loss:0.3564  g_loss:1.7229
# epoch:3763  d_loss:0.4312  g_loss:1.5422
# epoch:3764  d_loss:0.6096  g_loss:2.2176
# epoch:3765  d_loss:0.4720  g_loss:2.2917
# epoch:3766  d_loss:0.4655  g_loss:1.9807
# epoch:3767  d_loss:0.6133  g_loss:1.8376
# epoch:3768  d_loss:0.4817  g_loss:1.8914
# epoch:3769  d_loss:0.4495  g_loss:1.5974
# epoch:3770  d_loss:0.5774  g_loss:1.2824
# epoch:3771  d_loss:0.4915  g_loss:1.5873
# epoch:3772  d_loss:0.3484  g_loss:1.8141
# epoch:3773  d_loss:0.4407  g_loss:1.9141
# epoch:3774  d_loss:0.6063  g_loss:1.8016
# epoch:3775  d_loss:0.6227  g_loss:1.9779
# epoch:3776  d_loss:0.4790  g_loss:1.7580
# epoch:3777  d_loss:0.3479  g_loss:2.0342
# epoch:3778  d_loss:0.4561  g_loss:1.8208
# epoch:3779  d_loss:0.5960  g_loss:1.6388
# epoch:3780  d_loss:0.5063  g_loss:1.2857
# epoch:3781  d_loss:0.5670  g_loss:1.3557
# epoch:3782  d_loss:0.6139  g_loss:1.9518
# epoch:3783  d_loss:0.4282  g_loss:1.6581
# epoch:3784  d_loss:0.5114  g_loss:1.6713
# epoch:3785  d_loss:0.4832  g_loss:1.7966
# epoch:3786  d_loss:0.4029  g_loss:1.8502
# epoch:3787  d_loss:0.4073  g_loss:1.8993
# epoch:3788  d_loss:0.5214  g_loss:1.9078
# epoch:3789  d_loss:0.4581  g_loss:1.4170
# epoch:3790  d_loss:0.5921  g_loss:1.2847
# epoch:3791  d_loss:0.5371  g_loss:1.4458
# epoch:3792  d_loss:0.3933  g_loss:1.6442
# epoch:3793  d_loss:0.3685  g_loss:1.8775
# epoch:3794  d_loss:0.4958  g_loss:2.0974
# epoch:3795  d_loss:0.4268  g_loss:2.0707
# epoch:3796  d_loss:0.4911  g_loss:2.0077
# epoch:3797  d_loss:0.4816  g_loss:1.3595
# epoch:3798  d_loss:0.4706  g_loss:1.2981
# epoch:3799  d_loss:0.5215  g_loss:1.3769
# epoch:3800  d_loss:0.5421  g_loss:1.7325
# epoch:3801  d_loss:0.4804  g_loss:1.7520
# epoch:3802  d_loss:0.4591  g_loss:1.6892
# epoch:3803  d_loss:0.4639  g_loss:1.6948
# epoch:3804  d_loss:0.5047  g_loss:1.9305
# epoch:3805  d_loss:0.4560  g_loss:1.6189
# epoch:3806  d_loss:0.4307  g_loss:1.3039
# epoch:3807  d_loss:0.4829  g_loss:1.5327
# epoch:3808  d_loss:0.5783  g_loss:1.2168
# epoch:3809  d_loss:0.4749  g_loss:1.6611
# epoch:3810  d_loss:0.3892  g_loss:2.0214
# epoch:3811  d_loss:0.5183  g_loss:1.8812
# epoch:3812  d_loss:0.6007  g_loss:1.8244
# epoch:3813  d_loss:0.4309  g_loss:1.5357
# epoch:3814  d_loss:0.4414  g_loss:1.7018
# epoch:3815  d_loss:0.6508  g_loss:1.3718
# epoch:3816  d_loss:0.4463  g_loss:1.4219
# epoch:3817  d_loss:0.4239  g_loss:2.0715
# epoch:3818  d_loss:0.5543  g_loss:2.1316
# epoch:3819  d_loss:0.4559  g_loss:1.6980
# epoch:3820  d_loss:0.5794  g_loss:1.1786
# epoch:3821  d_loss:0.4730  g_loss:1.2509
# epoch:3822  d_loss:0.5123  g_loss:1.5084
# epoch:3823  d_loss:0.5114  g_loss:2.0346
# epoch:3824  d_loss:0.4962  g_loss:2.1124
# epoch:3825  d_loss:0.5165  g_loss:2.1948
# epoch:3826  d_loss:0.6731  g_loss:1.5944
# epoch:3827  d_loss:0.4444  g_loss:1.4085
# epoch:3828  d_loss:0.4626  g_loss:1.4352
# epoch:3829  d_loss:0.5230  g_loss:1.4872
# epoch:3830  d_loss:0.4198  g_loss:1.5004
# epoch:3831  d_loss:0.3354  g_loss:1.6923
# epoch:3832  d_loss:0.4222  g_loss:1.9973
# epoch:3833  d_loss:0.4890  g_loss:1.7896
# epoch:3834  d_loss:0.4638  g_loss:1.6077
# epoch:3835  d_loss:0.3733  g_loss:1.6072
# epoch:3836  d_loss:0.4887  g_loss:1.8120
# epoch:3837  d_loss:0.4009  g_loss:1.6511
# epoch:3838  d_loss:0.4131  g_loss:1.7943
# epoch:3839  d_loss:0.5722  g_loss:1.3966
# epoch:3840  d_loss:0.3715  g_loss:1.4031
# epoch:3841  d_loss:0.5710  g_loss:1.7143
# epoch:3842  d_loss:0.5348  g_loss:1.9259
# epoch:3843  d_loss:0.5711  g_loss:1.6703
# epoch:3844  d_loss:0.4983  g_loss:1.7146
# epoch:3845  d_loss:0.6468  g_loss:1.5837
# epoch:3846  d_loss:0.4558  g_loss:1.7033
# epoch:3847  d_loss:0.5516  g_loss:1.9081
# epoch:3848  d_loss:0.3315  g_loss:1.9479
# epoch:3849  d_loss:0.4967  g_loss:2.1677
# epoch:3850  d_loss:0.4822  g_loss:2.0294
# epoch:3851  d_loss:0.6081  g_loss:1.6732
# epoch:3852  d_loss:0.5136  g_loss:1.9565
# epoch:3853  d_loss:0.4556  g_loss:1.8125
# epoch:3854  d_loss:0.5709  g_loss:1.6162
# epoch:3855  d_loss:0.4923  g_loss:2.0568
# epoch:3856  d_loss:0.4608  g_loss:1.4800
# epoch:3857  d_loss:0.5092  g_loss:1.5139
# epoch:3858  d_loss:0.3680  g_loss:1.7903
# epoch:3859  d_loss:0.3011  g_loss:2.1805
# epoch:3860  d_loss:0.4020  g_loss:2.1019
# epoch:3861  d_loss:0.5077  g_loss:2.0019
# epoch:3862  d_loss:0.4061  g_loss:2.3671
# epoch:3863  d_loss:0.4567  g_loss:2.0201
# epoch:3864  d_loss:0.5743  g_loss:2.2780
# epoch:3865  d_loss:0.5641  g_loss:1.8289
# epoch:3866  d_loss:0.5220  g_loss:1.5032
# epoch:3867  d_loss:0.5865  g_loss:1.5549
# epoch:3868  d_loss:0.4285  g_loss:1.9282
# epoch:3869  d_loss:0.5706  g_loss:1.5346
# epoch:3870  d_loss:0.5019  g_loss:1.5282
# epoch:3871  d_loss:0.4472  g_loss:2.1348
# epoch:3872  d_loss:0.4534  g_loss:1.8960
# epoch:3873  d_loss:0.4798  g_loss:1.9632
# epoch:3874  d_loss:0.5726  g_loss:1.7193
# epoch:3875  d_loss:0.6820  g_loss:1.5574
# epoch:3876  d_loss:0.4921  g_loss:1.2648
# epoch:3877  d_loss:0.4936  g_loss:1.4674
# epoch:3878  d_loss:0.4515  g_loss:1.5473
# epoch:3879  d_loss:0.5707  g_loss:1.4256
# epoch:3880  d_loss:0.4661  g_loss:1.8004
# epoch:3881  d_loss:0.5574  g_loss:1.6361
# epoch:3882  d_loss:0.4820  g_loss:1.3190
# epoch:3883  d_loss:0.4928  g_loss:1.4590
# epoch:3884  d_loss:0.4792  g_loss:1.4404
# epoch:3885  d_loss:0.4375  g_loss:1.5843
# epoch:3886  d_loss:0.3981  g_loss:1.8965
# epoch:3887  d_loss:0.4874  g_loss:1.8665
# epoch:3888  d_loss:0.3582  g_loss:1.7675
# epoch:3889  d_loss:0.4450  g_loss:1.6480
# epoch:3890  d_loss:0.4976  g_loss:1.8335
# epoch:3891  d_loss:0.2515  g_loss:1.7249
# epoch:3892  d_loss:0.4388  g_loss:1.8481
# epoch:3893  d_loss:0.3231  g_loss:1.8814
# epoch:3894  d_loss:0.4537  g_loss:1.9689
# epoch:3895  d_loss:0.4505  g_loss:1.4372
# epoch:3896  d_loss:0.5076  g_loss:1.4689
# epoch:3897  d_loss:0.5216  g_loss:1.6963
# epoch:3898  d_loss:0.3622  g_loss:2.1793
# epoch:3899  d_loss:0.4973  g_loss:2.0857
# epoch:3900  d_loss:0.5160  g_loss:1.8661
# epoch:3901  d_loss:0.4328  g_loss:2.3046
# epoch:3902  d_loss:0.4425  g_loss:2.0388
# epoch:3903  d_loss:0.4867  g_loss:1.7266
# epoch:3904  d_loss:0.5247  g_loss:1.4114
# epoch:3905  d_loss:0.6038  g_loss:1.4643
# epoch:3906  d_loss:0.4346  g_loss:1.8644
# epoch:3907  d_loss:0.4136  g_loss:1.7921
# epoch:3908  d_loss:0.4599  g_loss:1.7331
# epoch:3909  d_loss:0.6351  g_loss:1.6402
# epoch:3910  d_loss:0.6774  g_loss:1.3036
# epoch:3911  d_loss:0.5093  g_loss:1.2791
# epoch:3912  d_loss:0.5957  g_loss:1.5717
# epoch:3913  d_loss:0.5209  g_loss:1.3836
# epoch:3914  d_loss:0.4802  g_loss:2.0162
# epoch:3915  d_loss:0.5240  g_loss:1.5266
# epoch:3916  d_loss:0.4536  g_loss:1.4119
# epoch:3917  d_loss:0.6010  g_loss:1.1514
# epoch:3918  d_loss:0.4938  g_loss:1.4896
# epoch:3919  d_loss:0.6432  g_loss:1.5301
# epoch:3920  d_loss:0.5507  g_loss:1.3617
# epoch:3921  d_loss:0.4478  g_loss:1.9654
# epoch:3922  d_loss:0.4901  g_loss:1.2401
# epoch:3923  d_loss:0.4960  g_loss:1.6031
# epoch:3924  d_loss:0.4282  g_loss:1.4997
# epoch:3925  d_loss:0.4647  g_loss:1.4465
# epoch:3926  d_loss:0.5077  g_loss:1.8231
# epoch:3927  d_loss:0.5405  g_loss:1.3930
# epoch:3928  d_loss:0.5780  g_loss:1.1264
# epoch:3929  d_loss:0.5216  g_loss:1.2710
# epoch:3930  d_loss:0.4539  g_loss:1.7648
# epoch:3931  d_loss:0.4574  g_loss:1.5267
# epoch:3932  d_loss:0.4866  g_loss:1.7771
# epoch:3933  d_loss:0.5151  g_loss:1.6789
# epoch:3934  d_loss:0.7433  g_loss:1.5041
# epoch:3935  d_loss:0.5578  g_loss:1.4537
# epoch:3936  d_loss:0.4983  g_loss:1.3832
# epoch:3937  d_loss:0.4618  g_loss:1.2183
# epoch:3938  d_loss:0.4614  g_loss:1.5876
# epoch:3939  d_loss:0.4326  g_loss:1.6631
# epoch:3940  d_loss:0.4853  g_loss:1.7465
# epoch:3941  d_loss:0.4417  g_loss:1.5707
# epoch:3942  d_loss:0.6555  g_loss:1.5691
# epoch:3943  d_loss:0.5047  g_loss:1.4609
# epoch:3944  d_loss:0.4240  g_loss:1.5837
# epoch:3945  d_loss:0.6735  g_loss:1.3699
# epoch:3946  d_loss:0.4260  g_loss:1.4468
# epoch:3947  d_loss:0.3712  g_loss:1.8653
# epoch:3948  d_loss:0.4788  g_loss:2.1595
# epoch:3949  d_loss:0.3321  g_loss:2.3964
# epoch:3950  d_loss:0.6047  g_loss:1.9965
# epoch:3951  d_loss:0.5423  g_loss:1.4337
# epoch:3952  d_loss:0.5095  g_loss:1.5977
# epoch:3953  d_loss:0.4466  g_loss:1.2980
# epoch:3954  d_loss:0.4091  g_loss:1.6575
# epoch:3955  d_loss:0.4479  g_loss:1.8830
# epoch:3956  d_loss:0.5714  g_loss:1.7172
# epoch:3957  d_loss:0.4467  g_loss:2.0128
# epoch:3958  d_loss:0.4134  g_loss:1.7968
# epoch:3959  d_loss:0.6612  g_loss:1.6158
# epoch:3960  d_loss:0.5907  g_loss:1.3939
# epoch:3961  d_loss:0.5992  g_loss:1.1623
# epoch:3962  d_loss:0.4234  g_loss:1.7322
# epoch:3963  d_loss:0.5214  g_loss:1.6449
# epoch:3964  d_loss:0.5560  g_loss:1.7478
# epoch:3965  d_loss:0.5784  g_loss:1.2257
# epoch:3966  d_loss:0.5535  g_loss:1.3374
# epoch:3967  d_loss:0.6228  g_loss:1.5627
# epoch:3968  d_loss:0.5563  g_loss:1.5211
# epoch:3969  d_loss:0.4944  g_loss:1.7469
# epoch:3970  d_loss:0.4556  g_loss:1.6567
# epoch:3971  d_loss:0.4742  g_loss:1.4336
# epoch:3972  d_loss:0.5886  g_loss:1.1583
# epoch:3973  d_loss:0.7355  g_loss:1.1998
# epoch:3974  d_loss:0.3934  g_loss:1.6064
# epoch:3975  d_loss:0.5418  g_loss:1.4850
# epoch:3976  d_loss:0.5660  g_loss:1.4610
# epoch:3977  d_loss:0.7201  g_loss:1.5507
# epoch:3978  d_loss:0.5539  g_loss:1.5920
# epoch:3979  d_loss:0.6226  g_loss:1.4486
# epoch:3980  d_loss:0.4597  g_loss:1.4079
# epoch:3981  d_loss:0.6127  g_loss:1.5088
# epoch:3982  d_loss:0.4868  g_loss:1.4717
# epoch:3983  d_loss:0.4846  g_loss:1.6787
# epoch:3984  d_loss:0.6602  g_loss:1.6467
# epoch:3985  d_loss:0.4588  g_loss:1.4328
# epoch:3986  d_loss:0.6057  g_loss:1.5613
# epoch:3987  d_loss:0.6429  g_loss:1.3730
# epoch:3988  d_loss:0.4850  g_loss:1.1954
# epoch:3989  d_loss:0.4934  g_loss:1.3559
# epoch:3990  d_loss:0.5952  g_loss:1.3867
# epoch:3991  d_loss:0.3645  g_loss:1.9695
# epoch:3992  d_loss:0.3790  g_loss:1.8886
# epoch:3993  d_loss:0.6105  g_loss:1.7645
# epoch:3994  d_loss:0.4588  g_loss:1.5067
# epoch:3995  d_loss:0.4635  g_loss:1.4625
# epoch:3996  d_loss:0.5191  g_loss:1.2616
# epoch:3997  d_loss:0.3927  g_loss:1.1652
# epoch:3998  d_loss:0.4507  g_loss:1.3274
# epoch:3999  d_loss:0.5107  g_loss:1.6829
# epoch:4000  d_loss:0.3648  g_loss:2.1138
# C:\Users\shha\anaconda3\envs\tf2\lib\site-packages\ipykernel_launcher.py:41: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
